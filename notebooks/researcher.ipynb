# %%
sample_email_body = """<table border="0" cellpadding="0" cellspacing="0" role="presentation" width="100%"><tbody><tr><td align="left" style="font-size:0;padding:0;word-break:break-word"><div style="font-family:Ubuntu,Helvetica,Arial,sans-serif;font-size:14px;font-weight:600;line-height:1;text-align:left;color:#333">New property</div></td></tr><tr><td align="left" style="font-size:0;padding:0;padding-top:5px;word-break:break-word"><div style="font-family:Ubuntu,Helvetica,Arial,sans-serif;font-size:14px;line-height:20px;text-align:left;color:#555">2991, Rue Edmond, Kirkland, Neighbourhood South East - Centris no. 10143620</div></td></tr><tr><td align="left" style="font-size:0;padding:0;padding-top:5px;word-break:break-word"><table border="0" cellpadding="0" cellspacing="0" role="presentation" style="border-collapse:separate;line-height:100%"><tbody><tr><td align="center" bgcolor="#5bb6bd" role="presentation" style="border:none;border-radius:3px;background:#5bb6bd" valign="middle"><a href="https://consumersharingqc.centris.ca/api/Retrieve/keaxSUWxiazulageVydegDWxXf/?id=10143620&amp;context=AlertViewListingSummary" style="display:inline-block;background:#5bb6bd;color:#fff;font-family:Ubuntu,Helvetica,Arial,sans-serif;font-size:14px;font-weight:400;line-height:120%;margin:0;text-transform:none;padding:10px 25px;border-radius:3px;text-decoration:none" target="_blank" data-saferedirecturl="https://www.google.com/url?q=https://consumersharingqc.centris.ca/api/Retrieve/keaxSUWxiazulageVydegDWxXf/?id%3D10143620%26context%3DAlertViewListingSummary&amp;source=gmail&amp;ust=1722259637945000&amp;usg=AOvVaw3At9Lg93yvT7i9CZUJN1Hd">View property</a></td></tr></tbody></table></td></tr></tbody></table>
"""

# %%
sample_listing_detail = """<body><div id="didomi-host" data-nosnippet="true" aria-hidden="true"></div><iframe name="__tcfapiLocator" title="__tcfapiLocator" style="display: none;"></iframe>
    <!-- Google Tag Manager (noscript) -->
    <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-558V6M" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
    <!-- End Google Tag Manager (noscript) -->

    <header id="header" style="--header-height: 64px;">
        <div class="promo-container">
            
        </div>
        <nav class="navbar navbar-expand fixed-top">
            <div class="mobile-menu-toggle"><i class="fas fa-bars"></i></div>
            <a class="navbar-brand active" itemprop="url" href="/en">
                <img itemprop="logo" src="https://cdn.centris.ca/public/qc/consumersite/images/logo-centris-small.gif" alt="Centris.ca">
                <strong>The Largest Number of Homes for Sale</strong>
            </a>
            <ul class="navbar-nav">
                <li class="nav-item property-search-nav-item section-item">
                    <a class="nav-link property-search-link" href="/en/properties~for-rent~dollard-des-ormeaux?view=Summary"><span>Search</span><i class="far fa-search"></i></a>
                </li>
                        <li class="nav-item dropdown dropdown-hover section-item">
                            <a class="nav-link" href="/en/buy">Buy</a>
                            <div class="dropdown-menu">
                                    <a class="dropdown-item" href="/en/properties~for-rent~dollard-des-ormeaux?view=Summary"><span>Find a property</span></a>
                                    <a class="dropdown-item" href="/en/buy/buying-with-real-estate-broker"><span>Buying with a broker</span></a>
                                    <a class="dropdown-item" href="/en/buy/house-buying-process"><span>Steps involved in buying</span></a>
                                    <a class="dropdown-item" href="/en/buy/risks-buying-without-real-estate-broker"><span>Risks of buying without a broker</span></a>
                            </div>
                        </li>
                        <li class="nav-item dropdown dropdown-hover section-item">
                            <a class="nav-link" href="/en/sell">Sell</a>
                            <div class="dropdown-menu">
                                    <a class="dropdown-item" href="/en/sell/selling-your-house"><span>Selling with a broker</span></a>
                                    <a class="dropdown-item" href="/en/sell/house-selling-process"><span>Steps involved in selling</span></a>
                                    <a class="dropdown-item" href="/en/sell/risks-selling-without-real-estate-broker"><span>Risks of selling without a broker</span></a>
                            </div>
                        </li>
                        <li class="nav-item dropdown dropdown-hover section-item">
                            <a class="nav-link" href="/en/my-real-estate-broker">My broker</a>
                            <div class="dropdown-menu">
                                    <a class="dropdown-item" href="/en/real-estate-brokers"><span>Find a broker</span></a>
                                    <a class="dropdown-item" href="/en/my-real-estate-broker/teaming-up-with-a-broker"><span>Teaming up with a broker</span></a>
                                    <a class="dropdown-item" href="/en/my-real-estate-broker/how-choose-real-estate-broker"><span>The 10 qualities of a good broker</span></a>
                                    <a class="dropdown-item" href="/en/my-real-estate-broker/testimonials"><span>What clients are saying</span></a>
                                    <a class="dropdown-item" href="/en/my-real-estate-broker/become-real-estate-broker"><span>Become a broker</span></a>
                            </div>
                        </li>
                        <li class="nav-item dropdown dropdown-hover section-item">
                            <a class="nav-link" href="/en/tools">Tools</a>
                            <div class="dropdown-menu">
                                    <a class="dropdown-item" href="/en/tools/community-profile"><span>Community profile</span></a>
                                    <a class="dropdown-item" href="/en/tools/real-estate-statistics"><span>Real estate statistics</span></a>
                                    <a class="dropdown-item" href="/en/tools/useful-links"><span>Useful links</span></a>
                                    <a class="dropdown-item" href="/en/blog"><span>Real estate blog</span></a>
                                    <a class="dropdown-item" href="/en/tools/calculator"><span>Calculator</span></a>
                                    <a class="dropdown-item" href="/en/newsletter"><span>Centris.ca Newsletter</span></a>
                            </div>
                        </li>
                <li class="menu-spacer"></li>
                    <li class="nav-item">
                        <a class="nav-link language-toggle" href="/fr/maison~a-vendre~kirkland/22918385?view=Summary">
                            FR
                        </a>
                    </li>

                <li class="nav-item dropdown">
                    <a class="nav-link btn-nav-link globe-menu" href="#" id="languageDropdownMenuLink" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                        <i class="far fa-globe"></i>
                    </a>
                    <div class="dropdown-menu dropdown-menu-right" aria-labelledby="languageDropdownMenuLink">
                                <a class="dropdown-item active no-auto-select-default" href="/en/properties~for-sale">
                                    Québec
                                </a>
<input id="otherTenantUrl" name="otherTenantUrl" type="hidden" value="/redirect/tenant/bc">                                <button class="dropdown-item other-tenant-item" data-toggle="modal" data-target="#redirection-modal">
                                    British Columbia
                                </button>
                                <a class="dropdown-item no-auto-select-default" href="/en/properties~for-sale~canada">
                                    Canada
                                </a>
                                <a class="dropdown-item no-auto-select-default" href="/en/properties~for-sale~usa">
                                    United States
                                </a>
                                <a class="dropdown-item no-auto-select-default" href="/en/properties~for-sale~international">
                                    International
                                </a>
                    </div>
                </li>

                    <li class="nav-item btn-nav-item user-menu-nav-item authenticated">
                        <div class="nav-link btn-nav-link user-menu-nav-link">
                            <div class="profile-thumbnail-circle">
                                <div class="profile-thumbnail initial">
                                        <img src="http://lh5.googleusercontent.com/-VnCOTUhoTqk/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdDrEIwcC_gnVoYObhy2nLLpwXy8A/photo.jpg" alt="" width="40" height="40">
                                </div>
                            </div>
                        </div>
                    </li>
            </ul>
            <div class="user-drawer">
                    <div class="user-drawer-name">Raj Paul</div>
                    <div class="drawer-divider"></div>
                <a class="drawer-item" href="/en/my-searches">
                    <span>
                        <i class="far fa-bell searches-icon"></i>
                        My searches
                        <span class="my-search-count">(2)</span>
                    </span>
                </a>
                <a class="drawer-item favorites" href="/en/my-favourites?view=Summary">
                    <span>
                        <i class="fas fa-heart favorites-icon"></i>
                        My favourites
                        <span class="js-label-count">(1)</span>
                    </span>
                </a>
                    <a class="drawer-item my-broker" href="/en/my-broker">
                        <span>
                            <i class="fa fa-user-friends broker-icon"></i>
                            My broker
                            <span class="js-label-count"></span>
                        </span>
                    </a>
                <a class="drawer-item" href="/en/my-profile">
                    <span>
                        <i class="far fa-cog account-icon"></i>
                        <span>My profile</span>
                    </span>
                </a>
                <a class="drawer-item dislikes" href="/en/hidden-properties?view=Summary">
                    <span>
                        <i class="far fa-eye-slash dislikes-icon"></i>
                        Hidden properties
                        <span class="js-label-count"></span>
                    </span>
                </a>
                <div class="drawer-divider"></div>
                <a class="dropdown-item" href="/en/logout">
                    Log out
                </a>
                    <a class="dropdown-item" href="https://zone.centris.ca/signin?1=1&amp;langue=en&amp;fromExternal=ConsumerSiteMenu">
                        Broker login
                    </a>
            </div>
            <div class="menu-sidebar">
                <ul class="links-list">
                    <li>
                        <a href="/en/properties~for-rent~dollard-des-ormeaux?view=Map&amp;geolocalization=enabled" tabindex="-1">
                            <span>Nearby</span>
                        </a>
                    </li>
                            <li class="collapse-menu">
                                <button data-toggle="collapse" data-target="#menu-sidebar-collapse0" aria-expanded="false" aria-controls="menu-sidebar-collapse0" class="collapse-btn" tabindex="-1">
                                    <span>Buy</span><i class="far fa-angle-down caret"></i>
                                </button>
                                <ul class="collapse" id="menu-sidebar-collapse0">
                                        <li>
                                            <a href="/en/properties~for-rent~dollard-des-ormeaux?view=Summary" tabindex="-1"><span>Find a property</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/buy/buying-with-real-estate-broker" tabindex="-1"><span>Buying with a broker</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/buy/house-buying-process" tabindex="-1"><span>Steps involved in buying</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/buy/risks-buying-without-real-estate-broker" tabindex="-1"><span>Risks of buying without a broker</span></a>
                                        </li>
                                </ul>
                            </li>
                            <li class="collapse-menu">
                                <button data-toggle="collapse" data-target="#menu-sidebar-collapse1" aria-expanded="false" aria-controls="menu-sidebar-collapse1" class="collapse-btn" tabindex="-1">
                                    <span>Sell</span><i class="far fa-angle-down caret"></i>
                                </button>
                                <ul class="collapse" id="menu-sidebar-collapse1">
                                        <li>
                                            <a href="/en/sell/selling-your-house" tabindex="-1"><span>Selling with a broker</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/sell/house-selling-process" tabindex="-1"><span>Steps involved in selling</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/sell/risks-selling-without-real-estate-broker" tabindex="-1"><span>Risks of selling without a broker</span></a>
                                        </li>
                                </ul>
                            </li>
                            <li class="collapse-menu">
                                <button data-toggle="collapse" data-target="#menu-sidebar-collapse2" aria-expanded="false" aria-controls="menu-sidebar-collapse2" class="collapse-btn" tabindex="-1">
                                    <span>My broker</span><i class="far fa-angle-down caret"></i>
                                </button>
                                <ul class="collapse" id="menu-sidebar-collapse2">
                                        <li>
                                            <a href="/en/real-estate-brokers" tabindex="-1"><span>Find a broker</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/my-real-estate-broker/teaming-up-with-a-broker" tabindex="-1"><span>Teaming up with a broker</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/my-real-estate-broker/how-choose-real-estate-broker" tabindex="-1"><span>The 10 qualities of a good broker</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/my-real-estate-broker/testimonials" tabindex="-1"><span>What clients are saying</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/my-real-estate-broker/become-real-estate-broker" tabindex="-1"><span>Become a broker</span></a>
                                        </li>
                                </ul>
                            </li>
                            <li class="collapse-menu">
                                <button data-toggle="collapse" data-target="#menu-sidebar-collapse3" aria-expanded="false" aria-controls="menu-sidebar-collapse3" class="collapse-btn" tabindex="-1">
                                    <span>Tools</span><i class="far fa-angle-down caret"></i>
                                </button>
                                <ul class="collapse" id="menu-sidebar-collapse3">
                                        <li>
                                            <a href="/en/tools/community-profile" tabindex="-1"><span>Community profile</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/tools/real-estate-statistics" tabindex="-1"><span>Real estate statistics</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/tools/useful-links" tabindex="-1"><span>Useful links</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/blog" tabindex="-1"><span>Real estate blog</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/tools/calculator" tabindex="-1"><span>Calculator</span></a>
                                        </li>
                                        <li>
                                            <a href="/en/newsletter" tabindex="-1"><span>Centris.ca Newsletter</span></a>
                                        </li>
                                </ul>
                            </li>
                    <li class="divider"></li>
                        <li class="collapse-menu">
                            <button data-toggle="collapse" data-target="#language-menu-sidebar-collapse" aria-expanded="false" aria-controls="language-menu-sidebar-collapse" class="collapse-btn" tabindex="-1">
                                Language<i class="far fa-angle-down caret"></i>
                            </button>
                            <ul class="collapse" id="language-menu-sidebar-collapse">
                                    <li>
                                            <a href="/fr/maison~a-vendre~kirkland/22918385?view=Summary" tabindex="-1">Français</a>
                                    </li>
                                    <li>
                                            <a class="active disabled" tabindex="-1" aria-disabled="true">
                                                English<i class="far fa-check"></i>
                                            </a>
                                    </li>
                            </ul>
                        </li>
                    <li class="collapse-menu">
                        <button data-toggle="collapse" data-target="#region-menu-sidebar-collapse" aria-expanded="false" aria-controls="region-menu-sidebar-collapse" class="collapse-btn" tabindex="-1">    
                            Region<i class="far fa-angle-down caret"></i>
                        </button>
                        <ul class="collapse" id="region-menu-sidebar-collapse">
                                <li>
                                        <a class="active no-auto-select-default" tabindex="-1">
                                            Québec
                                            <i class="far fa-check"></i>
                                        </a>
                                </li>
                                <li>
<input id="otherTenantUrl" name="otherTenantUrl" type="hidden" value="/redirect/tenant/bc">                                        <button class="other-tenant-item collapse-btn" data-toggle="modal" data-target="#redirection-modal" tabindex="-1">
                                            British Columbia
                                        </button>
                                </li>
                                <li>
                                        <a class="no-auto-select-default" href="/en/properties~for-sale~canada" tabindex="-1">
                                            Canada
                                        </a>
                                </li>
                                <li>
                                        <a class="no-auto-select-default" href="/en/properties~for-sale~usa" tabindex="-1">
                                            United States
                                        </a>
                                </li>
                                <li>
                                        <a class="no-auto-select-default" href="/en/properties~for-sale~international" tabindex="-1">
                                            International
                                        </a>
                                </li>
                        </ul>
                    </li>
                </ul>
            </div>
        </nav>
        <div class="menu-sidebar-backdrop" style="display: none;"></div>
        <div class="modal fade" id="redirection-modal">
            <div class="modal-dialog modal-dialog-centered">
                <div class="modal-content">
                    <div class="modal-header">
                        <h4 class="modal-title">Would you like to continue?</h4>
                        <button type="button" class="close" data-dismiss="modal">×</button>
                    </div>
                    <div class="modal-content">
                        <div>
                            By clicking on Continue, you will be redirected to <b>Realtylink.org</b>, where you'll find properties for sale and rent in British Columbia.
                        </div>
                    </div>
                    <div class="modal-footer">
                        <button type="button" class="btn btn-default" data-dismiss="modal">Cancel</button>
                        <a class="btn btn-primary" id="other-tenant-nav-button">Continue</a>
                    </div>
                </div>
            </div>
        </div>
        
    </header>

    <main role="main" style="padding-top: 65px;">
        <div class="alerts"></div>
        
<div class="modal fade" id="modal" role="dialog">
    <div class="modal-dialog modal-dialog-centered">
        <div class="modal-content">
            <div class="modal-header">
                <p class="modal-title">Message</p>
                <button type="button" class="close" data-dismiss="modal" title="Close">×</button>
            </div>
            <div class="modal-body"></div>
            <div class="modal-footer">
                <button type="button" class="btn btn-primary" data-dismiss="modal">Close</button>
            </div>
        </div>
    </div>
</div>

<div class="modal fade" id="modal-confirm" tabindex="-1" role="dialog" data-backdrop="static">
    <div class="modal-dialog modal-dialog-centered" role="document">
        <div class="modal-content">
            <div class="modal-header">
                <p class="modal-title"></p>
            </div>
            <div class="modal-body"></div>
            <div class="modal-footer">
                <button type="button" class="btn btn-outline-primary btn-cancel" data-dismiss="modal">Fermer</button>
                <button type="button" class="btn btn-primary btn-confirm">Confirmer</button>
            </div>
        </div>
    </div>
</div>

        
<script type="text/html" id="redirect-tooltip-favorite">
    <div class="d-flex flex-column redirectTooltip">
        <a href="javascript:void(0);" class="icon-close" data-dismiss="alert">&times;</a>
        <p class="message">Log in to add or remove favourites, and access them from anywhere!</p>
        <div class="d-flex">
            <a class="btn btn-outline-primary flex-fill" href="/en/create-account?returnUrl=%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385%3Fview%3DSummary%26utm_source%3Dalert%26utm_medium%3Demail%26utm_content%3Dlisting" role="button">Sign up</a>
            <a class="btn btn-primary flex-fill ml-1" href="/en/login?returnUrl=%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385%3Fview%3DSummary%26utm_source%3Dalert%26utm_medium%3Demail%26utm_content%3Dlisting" role="button">Log in</a>
        </div>
    </div>
</script>
        
<script type="text/html" id="redirect-tooltip-broker-favorite">
    <div class="d-flex flex-column redirectTooltip">
        <a href="javascript:void(0);" class="icon-close" data-dismiss="alert">&times;</a>
        <p class="message">Log in to select your broker.</p>
        <div class="d-flex">
            <a class="btn btn-outline-primary flex-fill" href="/en/create-account?returnUrl=%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385%3Fview%3DSummary%26utm_source%3Dalert%26utm_medium%3Demail%26utm_content%3Dlisting" role="button">Sign up</a>
            <a class="btn btn-primary flex-fill ml-1" href="/en/login?returnUrl=%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385%3Fview%3DSummary%26utm_source%3Dalert%26utm_medium%3Demail%26utm_content%3Dlisting" role="button">Log in</a>
        </div>
    </div>
</script>

<div id="broker-favorite-add-modal" class="modal fade legacy-reset modal-fullscreen-sm">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="modal-title h4">Share with my broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div id="broker-favorite-add-modal-body" class="modal-body">
            </div>
            <div class="modal-footer d-flex">
                <div id="broker-favorite-add-modal-error"></div>
                <button type="button" class="btn btn-outline-primary flex-fill" data-dismiss="modal">Cancel</button>
                <button id="broker-favorite-add-modal-confirm-button" type="button" class="btn btn-primary flex-fill">Confirm</button>
            </div>
        </div>
    </div>
</div>
<div id="broker-favorite-replace-modal" class="modal fade legacy-reset modal-fullscreen-sm">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="modal-title h4">Replace my broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div id="broker-favorite-replace-modal-body" class="modal-body">
            </div>
            <div class="modal-footer d-flex">
                <div id="broker-favorite-replace-modal-error"></div>
                <button type="button" class="btn btn-outline-primary flex-fill" data-dismiss="modal">Cancel</button>
                <button id="broker-favorite-replace-modal-confirm-button" type="button" class="btn btn-primary flex-fill">Confirm</button>
            </div>
        </div>
    </div>
</div>
<div id="broker-favorite-remove-modal" class="modal fade legacy-reset modal-fullscreen-sm">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="modal-title h4">Remove sharing for this broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div id="broker-favorite-remove-modal-body" class="modal-body">
            </div>
            <div class="modal-footer d-flex">
                <div id="broker-favorite-remove-modal-error"></div>
                <button type="button" class="btn btn-outline-primary flex-fill" data-dismiss="modal">Cancel</button>
                <button id="broker-favorite-remove-modal-confirm-button" type="button" class="btn btn-primary flex-fill">Confirm</button>
            </div>
        </div>
    </div>
</div>
<div id="broker-favorite-already-modal" class="modal fade legacy-reset modal-fullscreen-sm">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="modal-title h4">Share with my broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div id="broker-favorite-already-modal-body" class="modal-body">
            </div>
            <div class="modal-footer d-flex">
                <button type="button" class="btn btn-primary flex-fill" data-dismiss="modal">Close</button>
            </div>
        </div>
    </div>
</div>
        





<div class="wrapper title-results">
    <div class="site-padding">
        <div class="row region no-gutters">
            <a id="navgoback-result" class="fav-return-button" href="/en/properties~for-rent~dollard-des-ormeaux?view=Summary"><span class="icon-back"></span><i class="fas fa-chevron-double-left"></i>Return to results</a>
                <div id="search-block-nocontext" class="d-none ml-auto">
                    <button id="local-search" class="btn btn-search-filters" style="">
                        <span>
                            Lifestyle
                            <span id="llCount"></span>
                        </span>
                        <i class="far fa-walking"></i>
                    </button>
                    <section id="localLogicSection" class="localLogicSectionFilters" data-widget-id="9bba0e0a-2aa3-420f-acea-631ccbb8d36d"><div id="ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d" class="ll ll-widget-local-search" data-client="8062450d9"><div class="ll-search ll-filters ll-filters--grid"><div class="ll-container"><div class="ll-top-controls"><div class="ll-on-off"><style type="text/css">#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty input:checked~.state.p-success label {
  color: #5bb6bd;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty.p-switch.p-fill input:checked~.state:before {
  background-color: #5bb6bd !important;
  border-color: #5bb6bd !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty.p-switch.p-fill input:checked~.state label:after {
  background-color: #5bb6bd !important;
}</style><div class="pretty p-switch p-fill"><span class="ll-heatmaps-label">Lifestyle</span><input type="checkbox"><div class="state"><label><span class="ll-invisible"></span></label></div></div></div><div class="ll-caret-box ll-flip"><svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" width="10" height="10" viewBox="0 0 292.362 292.362" style="enable-background:new 0 0 292.362 292.362;" xml:space="preserve"><g><path d="M286.935,69.377c-3.614-3.617-7.898-5.424-12.848-5.424H18.274c-4.952,0-9.233,1.807-12.85,5.424C1.807,72.998,0,77.279,0,82.228c0,4.948,1.807,9.229,5.424,12.847l127.907,127.907c3.621,3.617,7.902,5.428,12.85,5.428s9.233-1.811,12.847-5.428L286.935,95.074c3.613-3.617,5.427-7.898,5.427-12.847C292.362,77.279,290.548,72.998,286.935,69.377z"></path></g></svg></div></div><div class="ll-filter-options"><div><style type="text/css">#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score:hover, #ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-score:hover .pretty .state label:before, #ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score:hover .pretty  .state label:before {
  border-color: #5bb6bd !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score .pretty input:checked~.state.p-success label:after, #ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty.p-toggle .state.p-success label:after {
  background-color: #f2f2f2 !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-score .pretty input:checked~.state.p-success label:after, #ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty.p-toggle .state.p-success label:after {
  background-color: #5bb6bd !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty.p-switch.p-fill input:checked~.state:before {
  background-color: #5bb6bd !important;
  border-color: #5bb6bd !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .pretty input:checked~.state.p-success label {
  color: #5bb6bd;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score.ll-selected {
  background-color: #5bb6bd !important;
  border-color: #5bb6bd;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score.ll-selected .ll-icon svg {
  stroke: white;
  fill: white;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score.ll-selected .ll-label {
  color: white;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-grid-score .pretty input:checked~.state.p-success .svg path {
  stroke: #5bb6bd !important;
  fill: #5bb6bd !important;
}

#ll-9bba0e0a-2aa3-420f-acea-631ccbb8d36d .ll-zoom-button {
  background-color: #5bb6bd;
}</style><div class="ll-category-section"><div class="ll-category-title">Transportation</div><div class="ll-grid-category-scores"><div class="ll-grid-score"><div class="ll-checkbox"><div class="pretty p-svg p-round"><input type="checkbox"><div class="state p-success"><svg class="svg svg-icon" viewBox="0 0 20 20"><path d="M7.629,14.566c0.125,0.125,0.291,0.188,0.456,0.188c0.164,0,0.329-0.062,0.456-0.188l8.219-8.221c0.252-0.252,0.252-0.659,0-0.911c-0.252-0.252-0.659-0.252-0.911,0l-7.764,7.763L4.152,9.267c-0.252-0.251-0.66-0.251-0.911,0c-0.252,0.252-0.252,0.66,0,0.911L7.629,14.566z" style="stroke: white; fill: white;"></path></svg><label></label></div></div></div><div class="ll-icon"><svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 512 512" xml:space="preserve" class="ll-svg ll-svg-pedestrian_friendly"><path d="M333.2,268.8c5.7,3.7,12.2,5.4,18.5,5.4c11.3,0,22.4-5.5,29-15.6c10.2-16,5.6-37.3-10.3-47.5l-87-56.2c-1.7-1.6-3.5-2.9-5.4-4.1c19.1-8,32.6-26.8,32.6-48.8c0-29.1-23.7-52.8-52.8-52.8S205,72.9,205,102c0,22.1,13.7,41.1,33.1,49l-4.7,1.2c-0.2,0-0.3,0.1-0.5,0.1l-56.4,20.3c-3.6,1.2-6.9,3.1-9.9,5.5c-4.4,2.6-8.1,6.2-10.9,10.6l-23.1,35.8c-5,7.7-6.7,17-4.7,26
.8c1.1-3,2.7-5.6,4.8-7.8c2.1-2.2,4.5-3.9,7.3-5.2c2.9-1.3,6-1.9,9.4-1.9c3.1,0,6.2,0.6,9.1,1.8c3,1.2,5.4,3.1,7.2,5.6l13.2-13.2c-3.4-3.9-7.9-6.8-13.4-8.8c-5.5-2-11.1-3-16.8-3c-6.1,0-11.9,1-17.2,3c-5.3,2-9.9,4.8-13.9,8.5c-3.9,3.7-7,8.1-9.3,13.4c-2.2,5.2-3.4,11.1-3.4,17.5c0,6.3,1.1,12.1,3.3,17.3c2.2,5.2,5.2,9.7,9.1,13.5c3.9,3.8,8.4,6.7,13.7,8.7c5.3,2,11,3.1,17.2,3.1c6.8,0,12.9-1.2,18.1-3.6c5.2-2.4,9.6-5.6,13.2-9.7L1898,138.5z"></path><polygon points="1905.5,55.6 1905.5,60.4 1905.2,60.4 1905.2,55.6 1903.6,55.6 1903.6,55.4 1907.1,55.4 1907.1,55.6 "></polygon><polygon points="1912.9,60.4 1912.9,55.7 1912.8,55.7 1910.8,60.4 1910.7,60.4 1908.7,55.7 1908.6,55.7 1908.6,60.4 1908.4,60.4 1908.4,55.4 1908.8,55.4 1910.7,59.9 1912.7,55.4 1913.1,55.4 1913.1,60.4 "></polygon><polyline points="871.9,161 880.7,166.6 880.3,202.7 872.2,197 "></polyline><polyline points="806,26 815.5,32.7 814.1,67.7 804.7,60.4 "></polyline></svg></a></div></div></div></section>
                </div>
        </div>
    </div>
</div>

<div name="results" class="wrapper even wrapper-results exception">
    <div id="property-result" class="site-padding">
        <div class="region">
            <div id="divMainResult">


    <div id="pre-localisation-section">
        <input type="hidden" id="isCrawler" value="false">
        <input type="hidden" id="calculatorListingPrice" value="749900">
        <input type="hidden" id="calculatorLink" value="/en/houses~for-sale~kirkland/22918385?view=Summary">
        <input type="hidden" id="singleBroker" value="true">

        <div class="property-summary-item templateSummaryItem">
            
<div id="contact-brokers-modal" class="modal fade legacy-reset modal-fullscreen-sm">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="h5 modal-title">Choose a real estate broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-body">
                <div class="h6">Listing broker</div>
                    <div class="mb-3">
                        

<div class="broker-info legacy-reset broker-info-selectable selected" itemscope="" itemtype="https://schema.org/RealEstateAgent" data-contact-url="/en/contact-broker/b8853/property/22918385" data-broker-id="26782" data-favorite-broker-id="" data-profile-id="bd7ce1ce129348c693b78f331a0cd685">
    <div itemprop="employee" itemscope="" itemtype="https://schema.org/Person">

        <div class="broker-info-container-broker selected">
            <div class="container broker-info-container pt-3">
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start">
                        <div class="position-absolute">
                            <img class="img-fluid broker-info-broker-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDD7514DDDDDDDDDDA&amp;t=c&amp;w=190&amp;h=220&amp;sm=m" alt="Pam Nikolopoulos, Residential and Commercial Real Estate Broker">
                        </div>
                    </div>
                    <div class="col-8 col-md-9">

                        <h1 class="broker-info__broker-title h5 mb-0" itemprop="name">Pam Nikolopoulos</h1>
                        <div class="p1" itemprop="jobTitle">Residential and Commercial Real Estate Broker</div>
                        <div class="p1"></div>
                    </div>
                </div>
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start"></div>
                    <div class="col-8 col-md-9">
                        <div class="broker-info-contact-broker mb-2">
                        </div>
                    </div>
                </div>
            </div>
        </div>
        <div class="broker-info-container-office">
            <div class="container broker-info-container">
                <div class="row">
                    <div class="col-4 col-md-3">
                    </div>
                    <div class="col-8 col-md-9">
                        <div>
                            <div class="row">
                                <div class="broker-info-office-info col-12 col-md-8">
                                    <div>
                                        <h2 class="p1 font-weight-medium m-0" itemprop="legalName" content="RE/MAX 3000 INC. Real Estate Agency">
                                            RE/MAX 3000 INC.
                                        </h2>
                                    </div>
                                    <div class="p1">
                                        Real Estate Agency
                                    </div>
                                </div>
                                <div class="col-12 col-md-4">
                                        <img class="img-fluid broker-info-office-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDDD858DDDDDDDDDDB&amp;t=b&amp;w=120&amp;h=90" alt="RE/MAX 3000 INC., Real Estate Agency">
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>
                    </div>
            </div>
            <div class="modal-footer d-flex">
                <button type="button" class="btn btn-outline-primary flex-fill" data-dismiss="modal">Cancel</button>
                <button id="contact-broker-select-confirm-btn" type="button" class="btn btn-primary flex-fill">Confirm</button>
            </div>
        </div>
    </div>
</div>
            

<div id="private-showing-broker-select-modal" class="modal legacy-reset modal-fullscreen-sm" tabindex="-1" role="dialog">
    <div class="modal-dialog modal-dialog-centered modal-dialog-scrollable">
        <div class="modal-content">
            <div class="modal-header">
                <div class="h5 modal-title">Choose a real estate broker</div>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-body">
                <div class="h6">Listing broker</div>
                    <div class="mb-3">
                        

<div class="broker-info legacy-reset broker-info-selectable selected" itemscope="" itemtype="https://schema.org/RealEstateAgent" data-contact-url="/en/contact-broker/b8853/property/22918385/interactive-showing" data-broker-id="26782" data-favorite-broker-id="" data-profile-id="bd7ce1ce129348c693b78f331a0cd685">
    <div itemprop="employee" itemscope="" itemtype="https://schema.org/Person">

        <div class="broker-info-container-broker selected">
            <div class="container broker-info-container pt-3">
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start">
                        <div class="position-absolute">
                            <img class="img-fluid broker-info-broker-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDD7514DDDDDDDDDDA&amp;t=c&amp;w=190&amp;h=220&amp;sm=m" alt="Pam Nikolopoulos, Residential and Commercial Real Estate Broker">
                        </div>
                    </div>
                    <div class="col-8 col-md-9">

                        <h1 class="broker-info__broker-title h5 mb-0" itemprop="name">Pam Nikolopoulos</h1>
                        <div class="p1" itemprop="jobTitle">Residential and Commercial Real Estate Broker</div>
                        <div class="p1"></div>
                    </div>
                </div>
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start"></div>
                    <div class="col-8 col-md-9">
                        <div class="broker-info-contact-broker mb-2">
                        </div>
                    </div>
                </div>
            </div>
        </div>
        <div class="broker-info-container-office">
            <div class="container broker-info-container">
                <div class="row">
                    <div class="col-4 col-md-3">
                    </div>
                    <div class="col-8 col-md-9">
                        <div>
                            <div class="row">
                                <div class="broker-info-office-info col-12 col-md-8">
                                    <div>
                                        <h2 class="p1 font-weight-medium m-0" itemprop="legalName" content="RE/MAX 3000 INC. Real Estate Agency">
                                            RE/MAX 3000 INC.
                                        </h2>
                                    </div>
                                    <div class="p1">
                                        Real Estate Agency
                                    </div>
                                </div>
                                <div class="col-12 col-md-4">
                                        <img class="img-fluid broker-info-office-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDDD858DDDDDDDDDDB&amp;t=b&amp;w=120&amp;h=90" alt="RE/MAX 3000 INC., Real Estate Agency">
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>
                    </div>
            </div>
            <div class="modal-footer d-flex">
                <button type="button" class="btn btn-outline-primary flex-fill" data-dismiss="modal">Cancel</button>
                <button id="private-showing-broker-select-confirm-btn" type="button" class="btn btn-primary flex-fill">Confirm</button>
            </div>
        </div>
    </div>
</div>
            <div>
                <div class="region-content">
                    <article id="overview" class="content-views" itemscope="" itemtype="http://schema.org/Product">
                        <meta content="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca" itemprop="name">
                        <div class="row property-tagline">
                            <div class="d-none d-sm-block house-info">
                                <div class="row" itemscope="" itemtype="https://schema.org/Place">
                                    <div class="col text-left pl-0" itemscope="" itemtype="https://schema.org/Place">
                                        <h1 itemprop="category">
                                            <span data-id="PageTitle">House for sale</span>
                                        </h1>
                                        <div class="d-flex mt-1">
                                            <button class="btn-open-map" onclick="Centris.OpenNewWindow('https://maps.google.ca/maps?z=15&amp;hl=en&amp;q=45.443723,-73.86379');">
                                                <i class="fas fa-map-marker-alt"></i>
                                            </button>
                                            <h2 itemprop="address" class="pt-1">
                                                38, Rue de Tarragone, Kirkland, Neighbourhood South West
                                            </h2>
                                        </div>
                                        <div itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
                                            <meta itemprop="latitude" content="45.4437230000">
                                            <meta itemprop="longitude" content="-73.8637900000">
                                        </div>
                                    </div>
                                    <div class="price-container">
                                        <div class="price text-right" itemprop="offers" itemtype="http://schema.org/Offer" itemscope="">
                                            <meta itemprop="priceCurrency" content="CAD">
                                            <meta itemprop="price" content="749900">
                                            <span id="BuyPrice" class="text-nowrap">$749,900</span>
                                            <span class="desc"></span>
                                            <span style="display:none;">or</span>
                                            <span class="text-nowrap"> <span class="desc"></span></span>
                                        </div>
                                            <div class="js-mortgage-payments-amount">
                                                


                                            </div>
                                    </div>
                                </div>
                            </div>
                            <div class="contact-info">
                                <div class="social-link">
                                    
<button class="btn btn-share" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
    <i class="far fa-share-alt"></i>
</button>

<div class="dropdown-menu dropdown-menu-right social-links" id="socialLinksCollapse">
    <div class="social-share share" data-sitepagecaller="PropertyViewSummary" data-nobroker="" data-noblog="" data-articletitle="" data-articledesc="" data-geographyurl="" data-geography="">
        <div class="sharethis" data-mlsnumber="22918385">
                <a class="facebook dropdown-item GTM-share-facebook" data-socialname="facebook" data-id="shareThisWithFacebook" onclick="facebookOpenGraphCheck('http://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.centris.ca%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385', 'https%3A%2F%2Fwww.centris.ca%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385');"><span>Facebook</span><i class="fab fa-facebook-f"></i></a>
                <a class="linkedin dropdown-item GTM-share-linkedin" data-socialname="linkedin" data-id="shareThisWithLinkedIn" onclick="onClickSocialShare('linkedin', 'http://www.linkedin.com/shareArticle?mini=true&amp;url=https%3A%2F%2Fwww.centris.ca%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385%3Flastest%3D202408111253&amp;summary=House+for+sale+in+Kirkland')"><span>LinkedIn</span><i class="fab fa-linkedin-in"></i></a>
                <a class="twitter dropdown-item GTM-share-twitter" data-socialname="twitter" data-id="shareThisWithTwitter" onclick="onClickSocialShare('twitter', 'https://twitter.com/share?url=https%3A%2F%2Fwww.centris.ca%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385&amp;text=House+for+sale+in+Kirkland')"><span>Twitter</span><i class="fab fa-twitter"></i></a>
                <a class="pinterest dropdown-item GTM-share-pinterest" data-socialname="pinterest" data-id="shareThisWithPinterest" onclick="onClickSocialShare('pinterest', 'http://pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.centris.ca%2Fen%2Fhouses%7Efor-sale%7Ekirkland%2F22918385&amp;media=https%3A%2F%2Fmspublic.centris.ca%2Fmedia.ashx%3Fid%3DADDD250DE127A7DDDDDDDDDDDA%26t%3Dpi%26w%3D640%26h%3D480%26sm%3Dc&amp;description=House+for+sale+in+Kirkland')"><span>Pinterest</span><i class="fab fa-pinterest-p"></i></a>
                <a class="courriel dropdown-item GTM-share-email" data-id="shareThisWithEmail" data-socialname="sendEmailbutton" onclick="onClickSocialShare('courriel')"><span>Email</span><i class="far fa-envelope"></i></a>
                <a class="dropdown-item js-copy-clipboard GTM-share-clipboard" data-copy-text="https://www.centris.ca/en/houses~for-sale~kirkland/22918385" data-copy-message="Link copied to clipboard">
                    <span>Copy link</span><i class="far fa-copy"></i>
                </a>
                <a class="print dropdown-item" data-socialname="print" data-id="shareByPrinting" href="/en/print/property/22918385" target="_blank"><span>Print</span><i class="far fa-print"></i></a>
        </div>
    </div>
</div>

<div class="modal fade" id="sendEmail" tabindex="-1" role="dialog" aria-labelledby="sendEmailLabel" aria-hidden="true">
    <div class="modal-dialog modal-dialog-centered" role="document">
        <div class="modal-content">
            <div class="modal-header">
                <h4 class="modal-title mt-0" id="sendEmailLabel">Send to a friend</h4>
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-body">
                <form id="sendEmailForm">
                    <div class="form-group">
                        <label for="Recipient">Emails (separated by ; )</label>
                        <input class="form-control" id="Recipient" name="Recipient" type="text" value="" data-rule-multiemail="true" required="">
                        <input type="hidden" name="urlToShare" id="urlToShare">
                        <input type="hidden" name="noMLS" id="noMLS" value="22918385">
                    </div>
                    <div class="form-group">
                        <label for="InputLastName" id="SpanLastName" class="first-child">My name</label>
                        <input class="form-control" type="text" name="LastName" required="" value="" id="InputLastName">
                    </div>
                    <div class="form-group">
                        <label for="InputEmail" id="SpanEmail" class="first-child">My email</label>
                        <input class="form-control" type="email" required="" name="email" value="" id="InputEmail">
                    </div>
                    <div class="form-group">
                        <label for="InputCommentaire" id="SpanCommentaire" class="first-child">Message (Up to 250 characters)</label>
                        <textarea class="form-control" id="InputCommentaire" name="InputCommentaire" cols="" rows=""></textarea>
                    </div>
                    <div class="d-flex justify-content-between mb-2 mt-2">
                        <div>
                            Send me a copy
                        </div>
                        <div class="custom-control custom-switch">
                            <input type="checkbox" class="custom-control-input" name="chk-sendCopy" id="chk-sendCopy">
                            <label class="custom-control-label" for="chk-sendCopy"></label>
                        </div>
                    </div>
                    <div class="d-flex justify-content-between">
                        <div>
                            Save my information
                        </div>
                        <div class="custom-control custom-switch">
                            <input type="checkbox" class="custom-control-input" name="chk-saveInfo" id="chk-saveInfo">
                            <label class="custom-control-label" for="chk-saveInfo"></label>
                        </div>
                    </div>
                    <div class="mt-3 mb-3 consent-message">
                        By clicking Send, you consent to your personal information being processed as set forth in <a href="/en/terms-use-privacy-policy?tab=PrivacyPolicy" target="_blank">Centris’ Privacy Policy</a>.
                    </div>
                    <div class="form-group d-flex justify-content-end mb-0">
                        <div>
                            <button type="button" data-dismiss="modal" class="btn btn-outline-primary" onclick="">Cancel</button>
                            <button type="button" class="btn btn-primary" onclick="sendEmail();">Send</button>
                        </div>
                    </div>
                </form>
            </div>
        </div>
    </div>
    
<script>
if (document.readyState === 'complete') {
    initRecaptcha('6LdHHJQaAAAAAO81RnRXQYPnVO3phMx3i-rElE4t', 'en', 'Light');
} else {
    window.onload = function() {
        initRecaptcha('6LdHHJQaAAAAAO81RnRXQYPnVO3phMx3i-rElE4t', 'en', 'Light');
    };
}
</script>
<div class="g-recaptcha" data-sitekey="6LdHHJQaAAAAAO81RnRXQYPnVO3phMx3i-rElE4t" data-callback="recaptchaCallback" data-badge="bottomright" data-type="image" data-size="invisible"><div class="grecaptcha-badge" data-style="bottomright" style="width: 256px; height: 60px; display: block; transition: right 0.3s; position: fixed; bottom: 14px; right: -186px; box-shadow: gray 0px 0px 5px; border-radius: 2px; overflow: hidden;"><div class="grecaptcha-logo"><iframe title="reCAPTCHA" width="256" height="60" role="presentation" name="a-e1bbph644iop" frameborder="0" scrolling="no" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox allow-storage-access-by-user-activation" src="https://www.google.com/recaptcha/api2/anchor?ar=1&amp;k=6LdHHJQaAAAAAO81RnRXQYPnVO3phMx3i-rElE4t&amp;co=aHR0cHM6Ly93d3cuY2VudHJpcy5jYTo0NDM.&amp;hl=en&amp;type=image&amp;v=_ZpyzC9NQw3gYt1GHTrnprhx&amp;size=invisible&amp;badge=bottomright&amp;cb=985qq0awcgd4"></iframe></div><div class="grecaptcha-error"></div><textarea id="g-recaptcha-response" name="g-recaptcha-response" class="g-recaptcha-response" style="width: 250px; height: 40px; border: 1px solid rgb(193, 193, 193); margin: 10px 25px; padding: 0px; resize: none; display: none;"></textarea></div><iframe style="display: none;"></iframe></div>


</div>
  

                                    
<div class="legacy-reset property-favorite property-favorite-default" data-listing-id="22918385" data-inscription-mode="Result">
        <div class="property-favorite-active d-none">
            <a class="property-favorite-button" title="Remove from my favourites" data-property-favorite-type="0">
                <i class="fas fa-heart property-favorite-heart-active "></i>
                <i class="fas fa-thumbs-up property-favorite-thumbs-up-active "></i>
                <i class="far fa-eye property-favorite-thumbs-down-active "></i>
            </a>
        </div>
        <div class=" property-favorite-inactive ">
            <a class="property-favorite-button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" title="Add to my favourites" data-offset="14,0">
                <i class="far fa-heart property-favorite-heart-default GTM-property-favorite-dropdown"></i>
            </a>
            <div class="dropdown-menu dropdown-menu-right">
                <a class="dropdown-item property-favorite-item GTM-property-favorite-favorite" data-property-favorite-type="1">Love<i class="fas fa-heart"></i></a>
                <a class="dropdown-item property-favorite-item GTM-property-favorite-like" data-property-favorite-type="2">Like<i class="fas fa-thumbs-up"></i></a>
                <hr style="margin:auto; width:90%">
                <a class="dropdown-item property-favorite-item GTM-property-favorite-dislike" data-property-favorite-type="4">Hide<i class="far fa-eye-slash"></i></a>
            </div>
        </div>
</div>
                                </div>
                                <div class="broker-contact-top">
                                    <a id="contact-brokers-btn" class="btn btn-primary d-flex align-items-center justify-content-center" href="/en/contact-broker/b8853/property/22918385">
                                        <span>Contact the real estate broker <i class="far fa-arrow-down"></i><i class="far fa-arrow-up"></i></span>
                                    </a>
                                </div>
                            </div>
                        </div>
                        <div>
                            <div class="thumbnail last-child first-child">
                                <script>
                                    window.MosaicPhotoUrls = ["https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A7DDDDDDDDDDDA&t=pi&w=640&h=480&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A89DDDDDDDDDD4&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A83DDDDDDDDDDC&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9EDDDDDDDDDDD&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A91DDDDDDDDDDA&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9DDDDDDDDDDDE&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A94DDDDDDDDDD0&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9CDDDDDDDDDDF&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9ADDDDDDDDDD1&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A90DDDDDDDDDD4&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9BDDDDDDDDDD2&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9FDDDDDDDDDDC&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A98DDDDDDDDDD4&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A99DDDDDDDDDD2&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A97DDDDDDDDDDC&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A93DDDDDDDDDDE&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A95DDDDDDDDDDA&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A96DDDDDDDDDD0&t=pi&w=320&h=240&sm=c","https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A71DDDDDDDDDD0&t=pi&w=320&h=240&sm=c"];
                                </script>
                                <div class="summary-photos photos-5">
                                    <div class="primary-photo-container">
                                        <div class="banners-container">
                                                <div class="banner new-price">
                                                    New price
                                                </div>
                                        </div>

                                        <a onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en',22918385,true, '999')" href="" role="button">
                                            <img class="" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A7DDDDDDDDDDDA&amp;t=pi&amp;w=640&amp;h=480&amp;sm=c" alt="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca">
                                        </a>
                                        <div class="photo-buttons legacy-reset ">
                                                <button class="btn photo-btn" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en',22918385,true, '999')" title="View photos">
                                                    19<i class="far fa-camera"></i>
                                                </button>
                                        </div>
                                    </div>
                                    <div class="secondary-photos-container">
                                            <a class="secondary-photo-container photo-2" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en', '22918385', true, '999', 2)" href="" role="button">
                                                <img class="" alt="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca" style="display: flex;" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A89DDDDDDDDDD4&amp;t=pi&amp;w=320&amp;h=240&amp;sm=c">
                                            </a>
                                            <a class="secondary-photo-container photo-3" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en', '22918385', true, '999', 3)" href="" role="button">
                                                <img class="" alt="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca" style="display: flex;" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A83DDDDDDDDDDC&amp;t=pi&amp;w=320&amp;h=240&amp;sm=c">
                                            </a>
                                            <a class="secondary-photo-container photo-4" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en', '22918385', true, '999', 4)" href="" role="button">
                                                <img class="" alt="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca" style="display: flex;" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A9EDDDDDDDDDDD&amp;t=pi&amp;w=320&amp;h=240&amp;sm=c">
                                            </a>
                                            <a class="secondary-photo-container photo-5" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en', '22918385', true, '999', 5)" href="" role="button">
                                                <img class="" alt="House for sale in Kirkland, Montréal (Island), 38, Rue de Tarragone, 22918385 - Centris.ca" style="display: flex;" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DE127A91DDDDDDDDDDA&amp;t=pi&amp;w=320&amp;h=240&amp;sm=c">
                                            </a>
                                    </div>
                                    <div class="photo-buttons legacy-reset ">
                                            <button class="btn photo-btn" onclick="event.preventDefault();addDataLayerPhotoViewer(22918385, 'Summary');initPhotoGallery('en',22918385,true, '999')" title="View photos">
                                                19<i class="far fa-camera"></i>
                                            </button>
                                    </div>
                                </div>
                            </div>
                            <div class="col-12 d-block d-sm-none house-info">
                                <div class="price" itemprop="offers" itemtype="http://schema.org/Offer" itemscope="">
                                    <meta itemprop="priceCurrency" content="CAD">
                                    <meta itemprop="price" content="749900">
                                    <span id="BuyPrice">$749,900</span><span class="desc"></span>
                                    <span style="display:none;;">or</span>
                                    <span></span><span class="desc"></span>
                                </div>
                                    <div class="js-mortgage-payments-amount pb-1">
                                        


                                    </div>
                                <div class="address" itemscope="" itemtype="https://schema.org/Place">
                                    <h1 itemprop="category">
                                        <span data-id="PageTitle">House for sale</span>
                                    </h1>
                                    <div class="d-flex mt-1">
                                        <button class="btn-open-map" onclick="Centris.OpenNewWindow('https://maps.google.ca/maps?z=15&amp;hl=en&amp;q=45.443723,-73.86379');">
                                            <i class="fas fa-map-marker-alt"></i>
                                        </button>
                                        <h2 itemprop="address">
                                            38, Rue de Tarragone, Kirkland, Neighbourhood South West
                                        </h2>
                                    </div>
                                    <div itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
                                        <meta itemprop="latitude" content="45.4437230000">
                                        <meta itemprop="longitude" content="-73.8637900000">
                                    </div>
                                </div>
                            </div>
                            <div class="row no-gutters detail-buttons mb-3">
                                    <div class="col-lg-3 col-6 detail-buttons-more-details">
                                        <button class="btn btn-primary btn-options GTM-detailedsheet-primary" onclick="RedirectToPasserelle('Top');">
                                            Detailed sheet<i class="fas fa-external-link-alt"></i>
                                        </button>
                                    </div>
                                    <div class="col-lg-3 col-6">
                                        <button class="btn btn-outline-primary btn-options onmap" onclick="Centris.OpenNewWindow('https://maps.google.ca/maps?z=15&amp;hl=en&amp;q=45.443723,-73.86379');">
                                            Map<i class="fas fa-map-marker-alt"></i>
                                        </button>
                                    </div>
                                    <div class="col-lg-3 col-6 streetview">
                                        <button class="btn btn-outline-primary btn-options" data-id="GoogleStreetViewUrl" onclick="Centris.OpenNewWindow('https://maps.google.com/maps?q=45.443723,-73.86379&amp;layer=c&amp;cbll=45.443723,-73.86379&amp;cbp=12,173.33,,0,5&amp;iframe=true&amp;width=950&amp;height=490&amp;hl=en');">
                                            Streetview<i class="fas fa-street-view"></i>
                                        </button>
                                    </div>
                            </div>
                        </div>
                        <div class="grid_3">
                            <div class="col-lg-12 description">
                                <div id="municipalityId" style="display: none !important; visibility: hidden">830</div>
                                <div class="region-nav">
                                </div>
                                <div class="legacy-reset">
                                    <h3 class="h5 mb-3">Features</h3>
                                </div>


                                <div class="row teaser">
                                        <div class="col-lg-3 col-sm-6 lifestyle" style="">
                                            <span class="ll-match-score noAnimation" data-id="22918385" data-lat="45.443723" data-lng="-73.86379"><span class="ll-score-color-default">?<span class="ll-tooltip"><p>Click to find out if this location matches your lifestyle</p></span></span></span>
                                            <span class="match-score-text">Lifestyle</span>
                                        </div>
                                            <div class="col-lg-3 col-sm-6 piece">
                                                7 rooms
                                            </div>
                                            <div class="col-lg-3 col-sm-6 cac">
                                                3 bedrooms
                                            </div>
                                            <div class="col-lg-3 col-sm-6 sdb">
                                                2 bathrooms
                                            </div>
                                </div>
                                <div style="display: none;">
                                    <span id="ListingId">22918385</span>
                                    <span id="RawPrice">749900</span>
                                    <span id="SummaryUrl">/en/houses~for-sale~kirkland/22918385?view=Summary</span>
                                    <span id="AlternateLanguageSummaryUrl">/fr/maison~a-vendre~kirkland/22918385</span>
                                    <span id="DetailedSheetURL">https://passerelle.centris.ca/redirect.aspx?NoMLS=22918385&amp;Lang=E&amp;source=centris.ca</span>
                                    <span id="EmbeddedDiffusionWebUrl">/en/houses~for-sale~kirkland/22918385/photos</span>
                                    <span id="PropertyLat">45.4437230000</span>
                                    <span id="PropertyLng">-73.8637900000</span>
                                    <span id="IsTrackingEnabled">true</span>
                                </div>
                                <div class="row">
                                    



            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Building style</div>
                <div class="carac-value"><span>Bungalow, Detached</span></div>
            </div>
            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Year built</div>
                <div class="carac-value"><span>1971</span></div>
            </div>
            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Lot area</div>
                <div class="carac-value"><span>5,400 sqft</span></div>
            </div>


                                    

<!-- ***************************************  section 2 ************************************ -->

            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Parking (total)</div>
                <div class="carac-value"><span>Driveway (2), Garage (1)</span></div>
            </div>
            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Fireplace/Stove</div>
                <div class="carac-value"><span>Wood fireplace</span></div>
            </div>
            <div class="col-lg-3 col-sm-6 carac-container">
                <div class="carac-title">Additional features</div>
                <div class="carac-value"><span>Basement 6 feet or +</span></div>
            </div>

    <div class="col-lg-3 col-sm-6 carac-container">
        <div class="carac-title">Move-in date</div>
        <div class="carac-value"><span>60 days after acceptance of promise to purchase or rent</span></div>
    </div>

    <div class="col-lg-3 col-sm-6 carac-container">
        <div class="walkscore">
            <a onclick="OpenWalkSocre(this);" title="Somewhat Walkable" data-url="https://www.walkscore.com/score/38-rue-de-tarragone-kirkland/lat=45.443723/lng=-73.86379/?utm_source=centris.ca&amp;utm_medium=ws_api&amp;utm_campaign=ws_api" style="" target="_blank"><span>66</span></a>
        </div>
    </div>


                                </div>
                            </div>
                            <div class="row description-row">
                                <div class="property-description col-md-6">
                                        <div class="legacy-reset">
                                            <h3 class="h5 mb-3">Description</h3>
                                        </div>
                                        <div itemprop="description">
                                            Well kept Bungalow in prime Kirkland South, walking distance to 2 parks,Beautiful kitchen redone in 2021 with quarts countertops - Possibility of 4th Bedroom in Basement - 2nd Bathroom with shower - Central a/c Quiet residential area,,perfect for young family !
                                        </div>
                                    <span class="mls">Centris No.&nbsp;<span id="ListingDisplayId" itemprop="sku" itemtype="http://schema.org/sku">22918385</span></span>
                                </div>
                                    <div class="col-md-6 d-none d-md-block more-details-row">
                                        <div class="more-details">
                                            <h4>Need more details?</h4>
                                            <div class="more-details-text">
                                                Visit the real estate broker's website to see the detailed sheet for this property.
                                            </div>
                                            <button class="btn btn-primary GTM-detailedsheet-secondary" onclick="RedirectToPasserelle('Bottom');">
                                                Detailed sheet<i class="fas fa-external-link-alt"></i>
                                            </button>
                                        </div>
                                    </div>
                            </div>
                            


<script>
    function toggleTables() {
        var cols = document.querySelectorAll('.financial-details-container .financial-details-table:not(:first-child)');
        for (var i = 0; i < cols.length; i++) {
            cols[i].style.display = cols[i].style.display === 'none' || cols[i].style.display === '' ? 'block' : 'none';
        }

        var toggleLink = document.getElementById('toggleLink');
        var seeMoreChevron = document.getElementById('see-more-chevron');
        var seeLessChevron = document.getElementById('see-less-chevron');

        if (toggleLink.textContent === 'See all financial details') {
            toggleLink.textContent = 'See less';
            
            seeMoreChevron.style.display = 'none';
            seeLessChevron.style.display = 'block';

        }
        else {
            toggleLink.textContent = 'See all financial details'

            seeMoreChevron.style.display = 'block';
            seeLessChevron.style.display = 'none';
        }
    }
</script>

<div class="financial-details-container container-fluid">
    <div class="legacy-reset">
        <h3 class="h5 mb-3">Financial details</h3>
    </div>
    <div class="row financial-details-tables">
        <div class="financial-details-table col-md-4">
            
<table class="table">
    <thead>
        <tr>
            <th colspan="2" class="col pl-0 financial-details-table-title">Municipal assessment (2024)</th>
        </tr>
    </thead>
    <tbody>
            <tr>
                <td>
                    Lot
                </td>
                <td class="text-right">
                    $308,500
                </td>
            </tr>
            <tr>
                <td>
                    Building
                </td>
                <td class="text-right">
                    $286,500
                </td>
            </tr>
    </tbody>
    <tfoot>
        <tr class="col pl-0 financial-details-table-total">
            <td class="font-weight-bold">Total</td>
            <td class="font-weight-bold text-right">$595,000</td>
        </tr>
    </tfoot>
</table>
        </div>
        <div class="financial-details-table col-md-4">
            
<table class="table">
    <thead>
        <tr>
            <th colspan="2" class="col pl-0 financial-details-table-title">Annual taxes</th>
        </tr>
    </thead>
    <tbody>
            <tr>
                <td>
                    Municipal (2024)
                </td>
                <td class="text-right">
                    $3,462
                </td>
            </tr>
            <tr>
                <td>
                    School (2023)
                </td>
                <td class="text-right">
                    $440
                </td>
            </tr>
    </tbody>
    <tfoot>
        <tr class="col pl-0 financial-details-table-total">
            <td class="font-weight-bold">Total</td>
            <td class="font-weight-bold text-right">$3,902</td>
        </tr>
    </tfoot>
</table>
        </div>
    </div>
    <div class="row">
        <div class="col pl-0 financial-detail-seemore">
            <div class="d-inline d-md-none" onclick="toggleTables()" id="toggleLink">See all financial details</div>
            <span id="see-less-chevron" class="fa fa-chevron-up"></span>
            <span id="see-more-chevron" class="fa fa-chevron-down"></span>
        </div>
    </div>
</div>


                                <div class="col-md-6 d-md-none mb-4 more-details-row">
                                    <div class="more-details">
                                        <h4>Need more details?</h4>
                                        <div class="more-details-text">
                                            Visit the real estate broker's website to see the detailed sheet for this property.
                                        </div>
                                        <button class="btn btn-primary GTM-detailedsheet-secondary" onclick="RedirectToPasserelle('Bottom');">
                                            Detailed sheet<i class="fas fa-external-link-alt"></i>
                                        </button>
                                    </div>
                                </div>


                            <div class="legacy-reset property-summary-item__brokers">
                                <div class="property-summary-item__brokers-section">

                                    <div class="property-summary-item__brokers-container">
                                        <div class="property-summary-item__brokers-title-container">
                                            <h3 class="property-summary-item__brokers-title h5">
                                                Listing broker
                                            </h3>
                                        </div>
                                        <div class="property-summary-item__brokers-content">
                                                <div class="position-relative">
                                                        <a href="/en/real-estate-broker~pam-nikolopoulos~re-max-3000-inc./b8853?view=Summary&amp;onlyonedisplay=true&amp;pback=true" class="stretched-link text-decoration-none" title="See my page"></a>
                                                    

<div class="broker-info legacy-reset  " itemscope="" itemtype="https://schema.org/RealEstateAgent" data-contact-url="/en/contact-broker/b8853/property/22918385" data-broker-id="26782" data-favorite-broker-id="" data-profile-id="bd7ce1ce129348c693b78f331a0cd685">
    <div itemprop="employee" itemscope="" itemtype="https://schema.org/Person">

        <div class="broker-info-container-broker ">
            <div class="container broker-info-container pt-3">
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start">
                        <div class="position-absolute">
                            <img class="img-fluid broker-info-broker-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDD7514DDDDDDDDDDA&amp;t=c&amp;w=190&amp;h=220&amp;sm=m" alt="Pam Nikolopoulos, Residential and Commercial Real Estate Broker">
                        </div>
                    </div>
                    <div class="col-8 col-md-9">
                                    <div class="broker-info__favorite-container broker-info__favorite-container-login">
                                        <button class="broker-info__favorite-button btn btn-outline-icon-only broker-info__favorite-button-js " type="button" title="Share with my broker" data-refresh-page="true" data-current-broker-id="" data-new-broker-id="26782">
                                            <i class="fal fa-user-friends"></i>
                                        </button>
                                    </div>

                        <h1 class="broker-info__broker-title h5 mb-0" itemprop="name">Pam Nikolopoulos</h1>
                        <div class="p1" itemprop="jobTitle">Residential and Commercial Real Estate Broker</div>
                        <div class="p1"></div>
                    </div>
                </div>
                <div class="row">
                    <div class="col-4 col-md-3 d-flex justify-content-start"></div>
                    <div class="col-8 col-md-9">
                        <div class="broker-info-contact-broker mb-2">
                                <div class="d-inline-block">
                                    <a class="btn btn-outline-icon-only " href="/en/contact-broker/b8853/property/22918385" title="Contact me">
                                        <i class="fal fa-envelope"></i>
                                    </a>
                                </div>
                                <div class="d-inline-block">
                                    <button class="btn btn-outline-icon-only" type="button" id="broker-info-phone" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" title="Call me">
                                        <i class="fal fa-phone"></i>
                                    </button>

                                    <div class="dropdown-menu dropdown-menu-right" aria-labelledby="broker-info-phone">
                                                <a class="dropdown-item" href="tel:514-235-0548" itemprop="telephone" content="514-235-0548" title="Call me">
                                                    514-235-0548<i class="fal fa-phone"></i>
                                                </a>
                                    </div>
                                </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
        <div class="broker-info-container-office">
            <div class="container broker-info-container">
                <div class="row">
                    <div class="col-4 col-md-3">
                    </div>
                    <div class="col-8 col-md-9">
                        <div>
                            <div class="row">
                                <div class="broker-info-office-info col-12 col-md-8">
                                    <div>
                                        <h2 class="p1 font-weight-medium m-0" itemprop="legalName" content="RE/MAX 3000 INC. Real Estate Agency">
                                            RE/MAX 3000 INC.
                                        </h2>
                                    </div>
                                    <div class="p1">
                                        Real Estate Agency
                                    </div>
                                </div>
                                <div class="col-12 col-md-4">
                                        <img class="img-fluid broker-info-office-image" src="https://mspublic.centris.ca/media.ashx?id=ADDD250DDDDD858DDDDDDDDDDB&amp;t=b&amp;w=120&amp;h=90" alt="RE/MAX 3000 INC., Real Estate Agency">
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>
                                                </div>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </article>
                </div>
            </div>
        </div>
    </div>
        <div id="localisation-section" class="templateSummaryItem">
            <div>
                <div class="region-content">
                    <section class="wrapper-localisation">
                        <div>
                            <input type="hidden" id="locallogicDataMin" name="locallogicDataMin" value="2">
                            
<input type="hidden" id="isLocalLogicComponentEnabled" value="true">
<input type="hidden" id="isCrawler" value="false">
    <div id="localLogicDiv" class="LocalLogic">
        <div class="header-localisation">
            <h3>
                Location
            </h3>
        </div>
        <div id="localLogicContentWidget"><div id="localContentWidget" style="height: 100%; width: 100%; display: flex; position: relative;"><iframe src="https://sdk.locallogic.co/sdks-app/v1/local-content?channelId=chn-68.79119962803411" name="Local Logic SDK" title="Local Logic SDK" style="width: 100%; height: 100%; border: 0px;"></iframe></div></div>
        <div id="localLogicUseCondition">
            In accordance with our <a href="/en/terms-use-privacy-policy" target="_blank">Terms of Use</a>, location data are provided to you “as-is”, without warranty. Any liability arising from location data is expressly excluded.
        </div>
    </div>

<script async="" src="https://sdk.locallogic.co/sdks-js/1.13.2/index.umd.js" onload="loadLocalContent()"></script>
<script type="text/javascript">

    function loadLocalContent() {
        (async () => {
            // Your API key or token
            const ll = LLSDKsJS("V3 lERfIZokEQL7BG2FbuKrX3xB328aF9po.c6b1aa0a-fb31-417c-95e1-5cf990e51871", {
                locale: "en",
                appearance: {
                    theme: "day",
                    // Add any other appearance changes here
                    variables: {
                        "--ll-color-primary": "#547589",
                        "--ll-color-primary-variant1": "#547589",
                        "--ll-border-radius-small": "8px",
                        "--ll-border-radius-medium": "16px",
                        "--ll-font-family": "Avenir, sans-serif"
                    }
                }
            });
            const container = document.createElement("div");
            container.setAttribute("id", "localContentWidget");
            // Set the styles of the container
            // With these styles the container will fill the height and width of the #widgetMap
            container.style.cssText = `
                                      height: 100%;
                                      width: 100%;
                                      display: flex;
                                    `;
            // This is the div that will contain the widget
            document.querySelector("#localLogicContentWidget").appendChild(container);
            // Set the lat and lng of the location
            const LAT = 45.4437230000;
            const LNG = -73.8637900000;
            lc = ll.create("local-content", container, {
                lat: LAT,
                lng: LNG,
                cooperativeGestures: false,
                marker: {
                    lat: LAT,
                    lng: LNG
                },
                zoom: 20
            });


        })();
    }

</script>
                        </div>
                    </section>
                </div>
            </div>
        </div>
    <div id="post-localisation-section">
            <div id="wrapper-statistics" class="wrapper even ">
                <div class="site-padding">
                    <div class="region region-grid">
                        <div class="region-content">
                            <article id="demography" class="content-views">
                                <div id="divStatistique" style="position: relative; float: left; width: 100%;">
                                    <h2>
                                        Discover
                                        <span>
                                                <span>Kirkland</span>
                                        </span>
                                    </h2>
                                    
    <div class="region-stats">
        <div class="summary">
            <div id="info">
                <table class="first">
                    <tbody><tr>
                        <td>Population (2016)</td>
                        <td><span data-id="PopulationQuantite">20,151</span></td>
                    </tr>
                    <tr>
                        <td>Population variation between 2011 and 2016</td>
                        <td><span data-id="PopulationVariation">-5%</span></td>
                    </tr>
                </tbody></table>
                <table class="last">
                    <tbody><tr>
                        <td>Population density</td>
                        <td><span data-id="PopulationDensite">2,093</span> hab/km<sup>2</sup></td>
                    </tr>
                    <tr>
                        <td>Unemployment rate (2016)</td>
                        <td><span data-id="TauxChomage">6%</span></td>
                    </tr>
                </tbody></table>
            </div>
        </div>

        <aside class="sidebar">
            <div id="menu">
                <div class="centrisSocioDemobutton active" id="btnGroupeAge" data-index="0">Age</div>
                <div class="centrisSocioDemobutton" id="btnRevenus" data-index="1">Incomes</div>
                <div class="centrisSocioDemobutton" id="btnMenagesPrives" data-index="2">Household</div>
                <div class="centrisSocioDemobutton" id="btnTypeFamille" data-index="3">Family</div>
                <div class="centrisSocioDemobutton" id="btnModeOccupation" data-index="4">Occupation</div>
                <div class="centrisSocioDemobutton" id="btnConstruction" data-index="5">Construction</div>
                <div class="centrisSocioDemobutton" id="btnTypeLogement" data-index="6">Housing</div>
                <div class="centrisSocioDemobutton" id="btnScolarite" data-index="7">Schooling</div>
                <div class="centrisSocioDemobutton" id="btnImmigration" data-index="8">Immigration</div>
                <div class="centrisSocioDemobutton" id="btnLangue" data-index="9">Language</div>
            </div>

            <div id="menuMobile" class="controls dropdown btn-group">
                <button class="btn control-select" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Age
                </button>
                <ul class="dropdown-menu dropdown-menu-select">
                    <li class="dropdown-item centrisSocioDemobutton" id="btnGroupeAge" data-index="0">Age</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnRevenus" data-index="1">Incomes</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnMenagesPrives" data-index="2">Household</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnTypeFamille" data-index="3">Family</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnModeOccupation" data-index="4">Occupation</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnConstruction" data-index="5">Construction</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnTypeLogement" data-index="6">Housing</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnScolarite" data-index="7">Schooling</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnImmigration" data-index="8">Immigration</li>
                    <li class="dropdown-item centrisSocioDemobutton" id="btnLangue" data-index="9">Language</li>
                </ul>
            </div>
        </aside>

        <div class="main-content" id="divMainSocioDemographicProfil1">
            <div id="divSocioDemographicProfil1" class="SocioDemographicProfilSommaire">
                <div class="titleChart">Population By Age Group</div>
                <div class="socioDemoChart k-chart" id="divChart" data-role="chart" style="position: relative; width: 225px; height: 225px;"><div class="averageText"><p>Average
42 years</p></div><svg style="width: 100%; height: 100%; overflow: hidden; left: 0px; top: -0.117188px;" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1"><defs><radialGradient id="kdef1" cx="112.5" cy="112.5" r="107.5" gradientUnits="userSpaceOnUse"><stop offset="0.6976744186046511" style="stop-color:#fff;stop-opacity:0;"></stop><stop offset="0.8488372093023255" style="stop-color:#fff;stop-opacity:0.3;"></stop><stop offset="0.9969767441860465" style="stop-color:#fff;stop-opacity:0;"></stop></radialGradient></defs><g><path d="M0 0 L 225 0 225 225 0 225Z" stroke="none" fill="none"></path><path d="M0 0 L 0 0 0 0 0 0Z" stroke="none" fill="#fff" fill-opacity="0"></path><g><g></g></g><g><g><g transform="matrix(1,0,0,1,0,0)"><path d="M112.5 5 C 129.557 5 146.599 9.134 161.759 16.95 176.92 24.766 190.173 36.25 200.067 50.144 L 173.593 68.996 C 166.691 59.302 157.444 51.29 146.867 45.837 136.29 40.384 124.4 37.5 112.5 37.5Z" stroke="none" fill="#70d2ed"></path><path d="M112.5 5 C 129.557 5 146.599 9.134 161.759 16.95 176.92 24.766 190.173 36.25 200.067 50.144 L 173.593 68.996 C 166.691 59.302 157.444 51.29 146.867 45.837 136.29 40.384 124.4 37.5 112.5 37.5Z" stroke="none" fill="url(https://www.centris.ca/en/houses~for-sale~kirkland/22918385?view=Summary&amp;utm_source=alert&amp;utm_medium=email&amp;utm_content=listing#kdef1)"></path></g><g transform="matrix(1,0,0,1,0,0)"><path d="M200.067 50.144 C 210.62 64.964 217.321 82.503 219.338 100.585 221.354 118.667 218.682 137.251 211.653 154.032 L 181.677 141.476 C 186.581 129.768 188.445 116.802 187.038 104.187 185.631 91.572 180.956 79.335 173.593 68.996Z" stroke="none" fill="#e95f55"></path><path d="M200.067 50.144 C 210.62 64.964 217.321 82.503 219.338 100.585 221.354 118.667 218.682 137.251 211.653 154.032 L 181.677 141.476 C 186.581 129.768 188.445 116.802 187.038 104.187 185.631 91
            </div>
        </div>
    </div>

                                </div>
                                <div class="clear"></div>
                            </article>
                        </div>
                    </div>
                </div>
                <hr>
            </div>

        <div id="divCalculator">
            


<section id="js-calc">
    <div class="wrapper even wrapper-calculator">
        <nav class="nav nav-tabs">
            <a class="nav-item nav-link active" style="cursor: pointer;" data-target="#CalculMntVersement" data-toggle="tab">
                <span>Calculate mortgage payments</span>
            </a>
                <a class="nav-item nav-link" style="cursor: pointer;" data-target="#CalculTaxe" data-toggle="tab">
                    <span>Estimated property transfer tax</span>
                </a>
            <a class="nav-item nav-link" style="cursor: pointer;" data-target="#CalculEmprunt" data-toggle="tab">
                <span>Calculate borrowing capacity</span>
            </a>
        </nav>
        <div class="site-padding">
            <div class="region region-grid">
                <div id="maindiv" class="container-fluid">
                    <div id="CalculMntVersement" data-group="groupCalculMntVersement" class="calculator-box tab-pane article active show">
                        <h3>Calculate mortgage payments<i></i></h3>
                        <div class="calcul-box" id="boxCalculMnt">
                            <div class="form-group col-12">
                                <label for="Calcul_prix">Price of property</label>
                                <input type="text" class="form-control" maxlength="8" id="Calcul_prix" data-type="integer" value="749,900"><span class="input-icon">$</span>
                                <p id="Calcul_prixError" class="error" style="display: none">Required field</p>
                            </div>
                            <div class="form-group col-12 mb-0">
                                <label for="Calcul_miseDeFond">Down payment</label>
                            </div>
                            <div class="row form-group">
                                <div class="col-auto">
                                    <div class="btn-group btn-group-toggle btn-sm p-0 down-payment-type-container" data-toggle="buttons">
                                        <label class="btn btn-outline-primary p-2 active">
                                            <input type="radio" name="downPaymentType" id="amount" value="Amount" checked="">$
                                        </label>
                                        <label class="btn btn-outline-primary p-2">
                                            <input type="radio" name="downPaymentType" id="percent" value="Percent">%
                                        </label>
                                    </div>
                                </div>
                                <div class="col js-downpayment-amount-container pr-0 pl-0" style=" display: block">
                                    <input type="text" class="form-control" maxlength="8" id="Calcul_miseDeFond" data-type="integer" value="0">
                                    <span class="input-icon-without-label">$</span>
                                </div>
                                <div class="col-3 js-downpayment-amount-container pl-0" style=" display: block">
                                    <span class="calcul-intermediaire form-control js-downpayment-percent"><span class="input-icon-without-label">%</span></span>
                                    <p id="Calcul_miseDeFondError" class="error" style="display: none">Required field</p>
                                </div>
                                <div class="col-3 js-downpayment-percent-container pr-0 pl-0" style="display: none">
                                    <input type="text" class="form-control" maxlength="2" id="Calcul_miseDeFondPourcentage" data-type="integer" value="0">
                                    <span class="input-icon-without-label">%</span>
                                </div>
                                <div class="col js-downpayment-percent-container pl-0" style="display: none">
                                    <span class="calcul-intermediaire form-control js-downpayment-amount"><span class="input-icon-without-label">$</span></span>
                                    <p id="Calcul_miseDeFondPourcentageError" class="error" style="display: none">Required field</p>
                                </div>
                            </div>
                            <div class="form-group col-12">
                                <label for="Calcul_emprunt">Mortgage amount</label>
                                <span id="Calcul_emprunt" class="calcul-intermediaire form-control">749,900<span class="input-icon">$</span></span>
                            </div>
                            <div class="row">
                                <div class="form-group col-6">
                                    <label for="Calcul_taux">Interest rate</label>
                                    <input type="text" class="form-control" maxlength="5" id="Calcul_taux" data-type="float" value=""><span class="input-icon">%</span>
                                    <p id="Calcul_tauxError" class="error" style="display: none">Required field</p>
                                </div>
                                <div class="form-group col-6">
                                    <label for="Calcul_amort">Amortization</label>
                                    <input type="text" class="form-control" maxlength="2" id="Calcul_amort" data-type="integer" value=""><span class="input-icon">years</span>
                                    <p id="Calcul_amortError" class="error" style="display: none">Required field</p>
                                </div>
                            </div>
                            <div class="form-group col-12">
                                <label> Payment frequency</label>
                                <div class="controls dropdown btn-group" id="SingleSelectCalcul_freq">
                                    <button class="btn community-select" id="SingleSelectCalcul_freqTmp" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" tabindex="-1" data-type="select" data-order="">
                                        Monthly
                                    </button>
                                    <ul class="dropdown-menu">
                                        <li class="dropdown-item option  active" data-option-value="12">Monthly</li>
                                        <li class="dropdown-item option " data-option-value="24">Bimonthly</li>
                                        <li class="dropdown-item option " data-option-value="26">Every 2 weeks</li>
                                        <li class="dropdown-item option " data-option-value="52">Weekly</li>
                                    </ul>
                                </div>
                            </div>
                            <div class="form-group col-12 total">
                                <button class="btn btn-primary btn-block" id="Calcul_btTotalVersement">Calculate</button>
                            </div>
                            <div class="form-group col-12">
                                <label>Payment amount</label>
                                <span id="Calcul_Versement" class="compute-result calcul-versement form-control"><span class="input-icon">$</span></span>
                            </div>
                            <div class="form-group col-12 Calcul_btVersement">
                                <button class="btn btn-primary monthly-payment btn-block" id="Calcul_btVersement">Monthly payment chart</button>
                            </div>
                            <table>
                                <tbody><tr class="mortgage-table">
                                    <td>
                                        <div class="container-overflow" id="tableMonthlyMortgage" style="display: none">
                                            <table class="divMonthlyArrayMortgageGeneral divMonthlyArrayMortgageOverflow">
                                                <tbody id="divMonthlyArrayMortgage" style="display: none;"></tbody>
                                            </table>
                                            <table style="display: none">
                                                <tbody id="templateMonthlyMortgage">
                                                    <tr>
                                                        <td class="first-child" headers="mois" id="mois"></td>
                                                        <td headers="interet" id="interet"></td>
                                                        <td headers="capital" id="capital"></td>
                                                        <td headers="solde" id="solde"></td>
                                                    </tr>
                                                </tbody>
                                            </table>
                                        </div>
                                    </td>
                                </tr>
                            </tbody></table>
                        </div>
                    </div>


                        <div id="CalculTaxe" data-group="groupChangeCalculTaxe" class="calculator-box tab-pane article">
                            <h3>Estimated property transfer tax<i></i></h3>
                            <!-- form element is used to prevent Chrome address autofill -->
                            <form class="form-group col-12">
                                <label for="search">Municipality</label>
                                <span class="twitter-typeahead" style="position: relative; display: inline-block;"><span class="twitter-typeahead" style="position: relative; display: inline-block;"><input type="search" class="form-control typeaheadCalculator border-primary typeahead" name="citySearch" id="citySearch" placeholder="" data-provide="dataset" autocomplete="off" spellcheck="false" dir="auto" style="position: relative; vertical-align: top;"><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto, sans-serif; font-size: 16px; font-style: normal; font-variant: normal; font-weight: 400; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-dataset"></div></div></span><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto, sans-serif; font-size: 16px; font-style: normal; font-variant: normal; font-weight: 400; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;">Kirkland</pre><div class="tt-menu" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-dataset"><div class="tt-suggestion tt-selectable"><strong class="tt-highlight">Kirkland</strong></div></div></div></span>
                                <p id="cityMessageError" class="error" style="display: none">Required field</p>

                                <input type="hidden" id="calcConfigId" name="calcConfigId" value="kirkland">
                                <input type="hidden" id="cityId" name="cityId" value="830">
                                <input type="hidden" id="cityName" name="cityName" value="Kirkland">
                            </form>
                            <div class="row">
                                <div class="form-group col-12">
                                    <label for="Calcul_prix">Price of property</label>
                                    <input type="text" class="form-control" maxlength="8" id="propriete" data-type="integer" value="749,900"><span class="input-icon">$</span>
                                    <p id="CalculPrixError" class="error" style="display: none">Required field</p>
                                </div>
                                <div class="form-group col-12">
                                    <label for="evalMunicipale">Municipal assessment total</label>
                                    <input type="text" class="form-control" maxlength="8" id="evalMunicipale" value="" data-type="integer"><span class="input-icon">$</span>
                                    <p id="evalMunicipaleError" class="error" style="display: none">Required field</p>
                                </div>
                            </div>
                            <div class="row">
                                <div class="form-group col-12 total">
                                    <button class="btn btn-primary btn-block" id="Calcul_btTotalMutation">Calculate</button>
                                </div>
                                <div class="form-group col-12">
                                    <label>Estimated property transfer tax</label>
                                    <span id="taxe" class="compute-result calcul-mutation form-control"><span class="input-icon">$</span></span>
                                </div>
                            </div>
                        </div>

                    <div id="CalculEmprunt" data-group="groupChangeCalculEmprunt" class="calculator-box tab-pane article">
                        <h3>Calculate borrowing capacity<i></i></h3>
                        <div class="row">
                            <div class="form-group col-12">
                                <label for="Versement2">Payment amount</label>
                                <input type="text" class="form-control" maxlength="8" id="Versement2" data-type="integer" value=""><span class="input-icon">$</span>
                                <p id="Versement2Error" class="error" style="display: none">Required field</p>
                            </div>
                        </div>
                        <div class="row">
                            <div class="form-group col-12">
                                <label> Payment frequency</label>
                                <div class="controls dropdown btn-group" id="SingleSelectCalcul_freq2">
                                    <button class="btn community-select" id="SingleSelectCalcul_freq2Tmp" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" tabindex="-1" data-type="select" data-order="">
                                        Monthly
                                    </button>
                                    <ul class="dropdown-menu">
                                        <li class="dropdown-item option active" data-option-value="12">Monthly</li>
                                        <li class="dropdown-item option" data-option-value="24">Bimonthly</li>
                                        <li class="dropdown-item option" data-option-value="26">Every 2 weeks</li>
                                        <li class="dropdown-item option" data-option-value="52">Weekly</li>
                                    </ul>
                                </div>
                            </div>
                            <div class="form-group col-6">
                                <label for="taux2">Interest rate</label>
                                <input type="text" class="form-control" maxlength="5" id="taux2" value="" data-type="float"><span class="input-icon">%</span>
                                <p id="taux2Error" class="error" style="display: none">Required field</p>
                            </div>
                            <div class="form-group col-6">
                                <label for="amort2">Amortization</label>
                                <input type="text" class="form-control" maxlength="2" id="amort2" value="" data-type="integer"><span class="input-icon">years</span>
                                <p id="amort2Error" class="error" style="display: none">Required field</p>
                            </div>
                            <div class="form-group col-12 total">
                                <button class="btn btn-primary btn-block" id="Calcul_btTotalEmprunt">Calculate</button>
                            </div>
                            <div class="form-group col-12">
                                <label>Mortgage amount</label>
                                <span id="emprunt2" class="compute-result calcul-emprunt form-control"><span class="input-icon">$</span></span>
                            </div>
                        </div>
                    </div>

                    <div class="calculator-notes">
                        <div id="page-calculator_notes_page_id">
<div id="block-ddb31825c7f286375efa61eeca16fd09">
<div class="container-fluid page-section template-onecolumn">
    <div class="body">
        <div class="row">
            <div class="first-item">
                <ul>
    <li>The amounts shown above are for information purposes only and do not include taxes, if applicable.</li>
    <li>You must purchase mortgage default insurance if your down payment is less than 20 per cent of the purchase price of the property. <a id="A1" href="https://www.cmhc-schl.gc.ca/en/buying/mortgage-loan-insurance-for-consumers" target="_blank">Click here for more information.</a></li>
    <li>
        Learn more about property transfer tax by
        <a href="http://www.oaciq.com/en/articles/property-transfer-duties" rel="external" target="_blank">clicking here.</a>
    </li>

</ul>
            </div>
        </div>
    </div>
</div></div>
</div>

                    </div>
                </div>
            </div>
        </div>
    </div>
</section>

        </div>
        
        
    </div>

            </div>
        </div> <!-- /region -->
    </div>
</div>

<div class="photoViewer photoViewerOnPage">
    <div id="gallery" class="gallery" ondragstart="return false;">
    <div class="close icon-close"></div>
    <div class="image-wrapper">
        <div class="wrap hideArrows">
            <div class="spinner-border text-primary"></div>
            <img id="fullImg" style="display:none;">
            <div class="logo"></div>
        </div>
        <div class="description"></div>
    </div>
    <div class="footer">
        <div class="thumbs">
            <div class="carousel-wrapper">
                <div class="carousel"><ul> </ul></div>
                <div class="nav">
                    <span class="nav-prev" style="user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); touch-action: none; display: none;"></span>
                    <span class="nav-next" style="user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); touch-action: none; display: none;"></span>
                </div>
            </div>
        </div>
    </div>
</div>
</div>


        <a href="#header" class="anchor" id="back-top">Back top</a>
    </main>

    <footer id="footer" class="footer">
        <div id="page-footer_page_id">
<div id="block-e4c9c0ef96213abbc8b666d62d845c4b">
<div class="container-fluid page-section template-onecolumn-empty">
    <div class="body">
        <div class="row">            
            <div style="border-top: 1px solid #000;"></div>
        </div>
    </div>
</div></div>
<div id="block-96e6a271249f3bf41b641d0308adbc1c" style=" background-color: #f5f5f5;">
<div class="container-fluid page-section template-threecols-33_33_33-1_2_3">
    <div class="body">
        <div class="row">
            <div class="first-item">
                <h4 class="mobile-center" style="text-align: left;"><strong><a href="/en/about" rel="nofollow"><span style="color:#414141">Discover Centris</span></a></strong></h4>
            </div>
            <div class="second-item">
                <h4 class="mobile-center" style="text-align: left;"><strong><a href="https://societecentris.ca/en/careers/" target="_blank" rel="nofollow"><span style="color:#414141">Join our team</span></a></strong></h4>
            </div>
            <div class="third-item">
                <h4 class="mobile-center" style="text-align: left;"><strong><a href="/en/contact-centris"><span style="color:#414141">Contact Centris</span></a></strong></h4>
            </div>
        </div>
    </div>
</div></div>
<div id="block-ae1ae0b4ec7467fe24405edef48c2a14" style=" background-color: #f5f5f5; color: #555;">
<style>
 #block-ae1ae0b4ec7467fe24405edef48c2a14 * {color: #555} 
</style>
<div class="container-fluid page-section template-threecols-33_33_33-1_2_3">
    <div class="body">
        <div class="row">
            <div class="first-item">
                <p class="mobile-hidden" style="text-align: left;">Centris.ca is powered by <a href="https://societecentris.ca/en/" target="_blank">Centris</a>, a company offering a wide range of technology tools and solutions tailored to meet the needs of Québec’s real estate brokers.</p>
<p class="mobile-hidden" style="text-align: left;"><a href="/en/about">Discover Centris</a></p>
            </div>
            <div class="second-item">
                <p class="mobile-hidden" style="text-align: left;">Are you looking for a stimulating work environment and interested in a career with us? We may have the perfect job for you.</p>
<p class="mobile-hidden" style="text-align: left;"><a href="https://societecentris.ca/en/careers/" target="_blank" rel="nofollow">See all available positions</a></p>
            </div>
            <div class="third-item">
                <p class="mobile-hidden" style="text-align: left;">Do you have any questions or comments for us? Simply fill in the form designed for this purpose.</p>
<p class="mobile-hidden" style="text-align: left;"><a href="/en/contact-centris">Contact Centris</a></p>
            </div>
        </div>
    </div>
</div></div>
<div id="block-62ee2480d9a0813bd19553a7d3fe16a1" style=" background-color: #eee;">
<div class="container-fluid page-section template-threecols-33_33_33-1_2_3">
    <div class="body">
        <div class="row">
            <div class="first-item">
                <p class="mobile-center" style="text-align: left;">
    <a href="https://www.facebook.com/centris.ca/" target="_blank"><img class="hover" src="https://cdn.centris.ca/public//qc/consumersite/62ee2480d9a0813bd19553a7d3fe16a1/facebook-icon.png"></a>&nbsp;&nbsp;<a href="https://www.linkedin.com/company/centris/mycompany/" target="_blank"><img class="hover" src="https://cdn.centris.ca/public//qc/consumersite/62ee2480d9a0813bd19553a7d3fe16a1/linkedin-icon.png"></a>&nbsp;&nbsp;
    <a href="https://apps.apple.com/ca/app/centris-ca/id604024675?l=en" target="_blank" class="GMT-ios-store-en"><img class="hover" src="https://cdn.centris.ca/public//qc/consumersite/62ee2480d9a0813bd19553a7d3fe16a1/apple-icon.png"></a>&nbsp;&nbsp;
    <a href="https://play.google.com/store/apps/details?id=com.centris_mobile&amp;hl=en" target="_blank" class="GTM-android-store-en"><img class="hover" src="https://cdn.centris.ca/public//qc/consumersite/62ee2480d9a0813bd19553a7d3fe16a1/android-icon.png"></a></p>
            </div>
            <div class="second-item">
                <button class="mobile-hidden" id="viewRegions" aria-expanded="false" aria-controls="collapseRegions" href="#collapseRegions" data-toggle="collapse">
    <p class="mobile-center" style="text-align: left;">View regions</p>
</button>
            </div>
            <div class="third-item">
        </ul>

    </div>
</div>
            </div>
        </div>
    </div>
</div></div>
</div>

    </footer>

    <footer id="poweredbycentris">
        <div class="container-fluid page-section template-threecols-33_33_33-1_2_3">
            <div class="body">
                <div class="row">
                    <div class="first-item">
                        <p class="mobile-center">
                            <a href="https://societecentris.ca/en/" target="_blank"><img src="https://cdn.centris.ca/public/cms/qc/consumersite/74b58f4e3b9bca7b93e43fa0dcb7c1ff/power-by-centris.png"></a>
                        </p>
                    </div>
                    <div class="second-item">
                        <br>
                        <p class="mobile-center">
                            <a href="/en/terms-use-privacy-policy">Terms of Use – Privacy Policy</a>
                        </p>   
                            <p class="mobile-center">
                                <a href="javascript:Didomi.notice.show()">Management of cookie consents</a>
                            </p>
                    </div>
                    <div class="third-item">
                        <br>
                        <p class="mobile-center">© Centris 2024. All rights reserved.</p>
                    </div>
                </div>
            </div>
        </div>
    </footer>

    <!-- Third-party JavaScript
    ================================================== -->
    <!-- Placed at the end of the document so the pages load faster -->
    <script src="https://cdn.jsdelivr.net/npm/jquery@3.5.1/dist/jquery.min.js" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" crossorigin="anonymous"></script>
    <script src="https://cdn.jsdelivr.net/npm/bootstrap@4.5.0/dist/js/bootstrap.bundle.min.js" integrity="sha256-Xt8pc4G0CdcRvI0nZ2lRpZ4VHng0EoUDMlGcBSQ9HiQ=" crossorigin="anonymous"></script>

    <!-- Custom JavaScript
    ================================================== -->
    <script type="text/javascript">
        window.ConsumerSite = {
            tenantId: "qc",
            tenantImagesUrl: "https://cdn.centris.ca/public/qc/consumersite/images/",
            languageCode: "en",
            googleMapOption: {
                gestureHandling: "greedy"
            },
            mySearchCount: 2,
            myDislikesCount: 0,
            myFavoritesCount: 1,
            mySavedSearchesCount: 2,
            myBrokerCount: 0,
            communityStatisticEnabled: true,
            useNavigatorCookieEnabled: false,
            dialogInsightSubscribeEnabled: true,
            currentUser: {
                isUserLogged: true,
                policies: {
                    canAccessChat: true,
                }
            },
            features: {
                activateChat: false,
                activateSignalR: false,
                activateSignalRSingleConnection: false,
                activateUserProfile: true
            },
            searchSettings: {
                maxResult: 5000,
                removeDislikeInNextSearch: true
            }

        };

        window.loggedIn = true;
    </script>


    <script src="/js/layout.js?v=MRI0Ue2-T1r_shM5Phsn_dova5_R5PQ0JvLLfWcBDlc"></script>
    <script src="/js/external-libs.js?v=ZUe7hCP7vnwM1sNSJ9z2HfX7IQtULhv5bPgkcqAvVGA"></script>
    <script src="/js/centris-framework.js?v=mdMJmO5gM_CoW_amS-Eu_gZcMPgvX-emiSqG1sAVhj4"></script>
    <script src="/js/main.js?v=9mudoQQamNVClgXhW_ytbMujiLO4Bxt1oSZUmqmO3xI" defer=""></script>

    
    <script type="text/javascript" src="https://maps.google.com/maps/api/js?key=AIzaSyBUYhp-C4t4APaL2H5a28461OrOY4AECZQ"></script>
    <script src="/js/typeahead.bundle.min.js?v=EAzCY2nZ6HDLcuEB2i7CdBk2IZdG__0EM46NriWCZRw"></script>


    <script src="https://cdn.jsdelivr.net/npm/bootstrap-datepicker@1.9.0/dist/js/bootstrap-datepicker.min.js" integrity="sha256-bqVeqGdJ7h/lYPq6xrPv/YGzMEb6dNxlfiTUHSgRCp8=" crossorigin="anonymous"></script>

    <script src="/js/select2.min.js?v=OQ1MvyMOgLGbm6IPSYzqr9EzsJrMgNiIB5wun-_7OAI"></script>

    <script src="https://cdn.jsdelivr.net/npm/bootstrap-slider@10.6.2/dist/bootstrap-slider.min.js" integrity="sha256-oj52qvIP5c7N6lZZoh9z3OYacAIOjsROAcZBHUaJMyw=" crossorigin="anonymous"></script>

    <script src="/js/jquery.blockUI.min.js?v=qVx9cIO_HqhO8vSJSDK7unZb-hkkjQZwp0dDd3p5LtE"></script>
    <script src="/js/lodash-custom.js?v=LaFT8O234mLVnuJdSx6D4zK09W0SThNILwdqkEnDxkQ"></script>
    <script src="/js/property.js?v=JrySOacSF5bIGxETd2w98hbcDbhNr2q9rbyqrvrjsXA"></script>
    <script src="/js/property-result.js?v=B-1lYTHkGtZNf3qzIEVlMum4u7VIyurw3MK1CjTHsA8"></script>
    
    <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1172843942799471");fbq("track","PageView");</script>
    <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1172843942799471&amp;ev=PageView&amp;noscript=1"></noscript>
    
    <script src="/js/maps.js?v=sJEHfzyKOiPwdlcm2jYhaxO5gqBPASZts_kk7W3hmx0"></script>
    <script src="/js/kendo.js?v=dvtR8OixFqGITsw2mGHsfHpnR8jeYmWkW6izYgjdFuw"></script>
    <script src="/js/recaptcha.js?v=SiZuarRCZvsZp2B1SFUBTSO-bKVCBqz2cQxHJc6qbwE"></script>
    <script src="/js/property-favorite.js?v=OWZN7WBNLHa7yAlqoRFKaEVBCml7XKeehfVIO8tg3QI"></script>
        <script src="/js/my-broker.js?v=MW3N8zY4RnpExX8eckZxM5v0SWRZFR95ymkr6O17lMk"></script>

        <script>
            $(function () {
                $("#local-search").hide();
                $("div.lifestyle").hide();               
                localLogicService.AddLocalLogicCallback('initLocalLogicSearch');
            });
        </script>
    <script type="text/javascript">
          
        window.LocalLogicUrl = 'https://cdn.locallogic.co/sdk/?token=8062450d9ee46fbf4f3069b11f00ccc1b0f7044c662eae234124c2f1967dfdc53b4a5eea0fdd4c7f';

        Centris.Page = $.extend(true, {}, Centris.Page);
        var currentId = '';
        var result;

        // <!-- Ouvrir et fermer les panneaux calculatrice et statistiques --
        function calculBtnClick() {
            $('#calculBtn').toggleClass("open");
            toggleDiv('divCalculator', 'wrapper-statistics');

            $('#statsBtn').removeClass("open");
        }

        function statsBtnClick() {
            $('#statsBtn').toggleClass("open");
            toggleDiv('wrapper-statistics', 'divCalculator');

            $('#calculBtn').removeClass("open");
        }

        function toggleDiv(slideToggleId, slideUpId, slideUpId2, topHeight) {
            if (topHeight == undefined) {
                topHeight = 0;
            }
            var stoggleObj = $('#' + slideToggleId);
            stoggleObj.slideToggle();
            $('#' + slideUpId).slideUp();
            if (slideUpId2 !== undefined) {
                $('#' + slideUpId2).slideUp();
            }
            if (!stoggleObj.is('visible')) {
                setTimeout(function () {
                    $("html, body").animate({ scrollTop: $("#" + slideToggleId).offset().top - topHeight });
                    return false;
                },
                    500);
            }
        }

        function RedirectToPasserelle(buttonPosition) {
            Centris.SendEventToGoogleTagManager({
                'event': 'detailedsheet-enter',
                'mls id': parseInt($("#ListingId").text()),
                'button': buttonPosition
            });

            if ($("#IsTrackingEnabled").text() === "true") {
                Centris.Property.TrackingService.trackProprieteAffichage(parseInt($('#ListingId').text()), "Passerelle");
            }

            Centris.OpenNewWindow($("#DetailedSheetURL").text());
        }

        function OpenWalkSocre(me) {
            Centris.OpenNewWindow($(me).attr('data-url'));
        }

        var pMap;
        $(document).ready(function () {                     
          
            window.centrisLanguage = 'en';
            Centris.Localization.setCurrentLanguage(window.centrisLanguage);

            window.InscriptionMode = 'Result';           

            window.GoogleShare = 'https://plus.google.com/share?url=';
            window.LinkedInShare = 'http://www.linkedin.com/shareArticle?mini=true&url=';
            window.TwitterShare = 'https://twitter.com/share?url=';
            window.FacebookShare = 'http://www.facebook.com/sharer.php?u=';
            window.MlsNumber = '22918385';
            window.ProfileLifeStyles = JSON.parse(JSON.stringify([]));

            //message pour le search Title
            messageFavoriTitle = "You do not have any favorites.";
            messageInvalidSuperficie = "properties in your list of favourites";
            window.ResourcesQuartier = "Neighbourhood";                    
                     

            $('.js-join-virtual-open-house').click(function () {
                Centris.SendEventToGoogleTagManager({
                    'event': 'virtual-open-house',
                    'mls id': $("#ListingId").text(),
                    'link': "join"
                });
            });
            $('.js-add-calendar-virtual-open-house').click(function (event) {
                if ($(this).data('icalendar') && window.navigator.msSaveOrOpenBlob !== undefined) {
                    event.preventDefault();
                    var calendarData = $(this).data('icalendar');
                    var fileName = $(this).data('filename')
                    var blob = new Blob([calendarData], { type: 'text/calendar' });
                    window.navigator.msSaveOrOpenBlob(blob, fileName);
                }
                Centris.SendEventToGoogleTagManager({
                    'event': 'virtual-open-house',
                    'mls id': $("#ListingId").text(),
                    'link': "calendar",
                    'option': $(this).data('calendar-app')
                });
            });

            documentReadyEnd();

            // fin du document ready
        });

        function documentReadyEnd() {
           
            Centris['result'] = result = new Centris.Result();

            window.PageMode = 'Summary';
            if (window.PageMode == "Summary" && true) {
                var latitude = 45.4437230000;
                var longitude = -73.8637900000;
                var latlng = { lat: latitude, lng: longitude };
                Centris['result'].CheckStreetViewAvailability(latlng);
            }

            result.Initialize();
        }

        /***********************************************************
         Local Logic - Local Maps Widget
         Centris implementation
        ***********************************************************/
        var localMapsWidget;

        // This function will be called when the Local Logic SDK is loaded and ready.
        // Feel free to modify and ajust the look and feel.
        function initLocallogic() {

            var mapContainer = document.getElementById('map-container');
            var uiContainer = document.createElement('div');
            var cssContainer = document.createElement('style');
            cssContainer.setAttribute('type', 'text/css');
            cssContainer.innerText = "#locallogicLocalMaps{position: absolute;top: 20%;right: 52px; z-index: 1000;}#ll-local-maps-toggle .ll-filters.ll-maps {box-shadow: none !important; border-radius:0px;}";

            uiContainer.setAttribute('id', 'locallogicLocalMaps');
            mapContainer.appendChild(cssContainer);
            mapContainer.appendChild(uiContainer);

            // Important line where the Local Maps widget is instanciated.
            localMapsWidget = new locallogic.LocalMaps('locallogicLocalMaps', {
                googleMapsMap: window.pMap.getMap(),
                adjustZoom: 11,
                locale: document.getElementsByTagName('html')[0].getAttribute('lang'),
                showZoomButton: false,
                color: '#547589'
            });

            var eElement = document.getElementById('map-toolbar-menu');
            var newFirstElement = document.createElement('div');
            newFirstElement.setAttribute('class', 'btn-container');
            newFirstElement.setAttribute('id', 'll-local-maps-toggle');
            newFirstElement.innerHTML = '<a href="javascript:;" class="btn-map btn-locallogic"></a>';

            var isHidden = true;
            var firstClick = true;
            newFirstElement.onclick = function () {
                if (isHidden) {
                    localMapsWidget.showUI();
                    isHidden = false;
                } else {
                    localMapsWidget.hideUI();
                    isHidden = true;
                }
                if (firstClick) {
                    localMapsWidget.enable();
                    firstClick = false;
                }
            }
            eElement.insertBefore(newFirstElement, eElement.firstChild);
            localMapsWidget.hideUI();
            $('#btn-heatmap').closest('div').remove();

            jQuery(document).mouseup(function (e) {
                var container = jQuery('#locallogicLocalMaps');
                var triggerButton = jQuery('#ll-local-maps-toggle');
                var mapsButton = jQuery('.gmnoprint');
                if (!container.is(e.target) && container.has(e.target).length === 0 &&
                    # !triggerButton.is(e.target) && triggerButton.has(e.target).length === 0 &&
                    # !mapsButton.is(e.target) && mapsButton.has(e.target).length === 0) {
                    localMapsWidget.hideUI();
                    isHidden = true;
                }
            });
        }

        function waitUntilLocalSearchReady(localLogicSearchWidget) {
            var isReady = localLogicSearchWidget.isReady();
            if (!isReady) {
                setTimeout(waitUntilLocalSearchReady, 200, localLogicSearchWidget);
            }
            else {
                localLogicSearchWidget.match(window.ProfileLifeStyles);
                localLogicSearchWidget.reloadLocations();
                if (window.ProfileLifeStyles.length > 0) {
                    var llcount = document.getElementById("llCount");
                    if (llcount) {
                        llcount.textContent = '(' + window.ProfileLifeStyles.length + ')';
                    }
                }
            }
        }

        function initLocalLogicSearch() {

            $("#local-search").show();
            $("div.lifestyle").show();            

            var localLogicSearchWidget = new locallogic.LocalSearch('localLogicSection', {
                displayAs: 'grid',
                locale: document.getElementsByTagName('html')[0].getAttribute('lang'),
                color: '#5bb6bd'
            });

            waitUntilLocalSearchReady(localLogicSearchWidget);

            window.localLogicSearchWidget = localLogicSearchWidget;

            $('#local-search').click(function () {
                if ($('#localLogicSection').css("display") == "none") {
                    $('#localLogicSection').show();

                    $('#local-search').addClass('localSearchOpen');

                    $('.ll-match-score').each(function () {
                        this.classList.remove('noAnimation');
                    });
                }
                else {
                    $('#localLogicSection').hide();

                    $('#local-search').removeClass('localSearchOpen');

                    Centris.fn.wsSend("profiles/" + "bd7ce1ce129348c693b78f331a0cd685" + "/lifestyles", getLocalLogicSelection());
                }
            });

            $('#localLogicSection').click(function () {
                setTimeout(function () {
                    var llcount = document.getElementById("llCount");
                    var selectionLength = window.localLogicSearchWidget.selection().length;

                    if (llcount) {
                        llcount.textContent = selectionLength > 0 ? '(' + selectionLength + ')' : "";
                    }
                }, 100);
            });

            $(document).click(function (e) {

                //Polyfill for IE9+
                if (!Element.prototype.matches) {
                    Element.prototype.matches = Element.prototype.msMatchesSelector ||
                        Element.prototype.webkitMatchesSelector;
                }

                if (!Element.prototype.closest) {
                    Element.prototype.closest = function (s) {
                        var el = this;

                        do {
                            if (el.matches(s)) return el;
                            el = el.parentElement || el.parentNode;
                        } while (el !== null && el.nodeType === 1);
                        return null;
                    };
                }
                //end polyfill

                if (e.target.closest('#localLogicSection')) return;
                if (e.target.closest('#local-search')) return;

                if ($('#localLogicSection').css("display") != "none") {
                    $('#localLogicSection').hide();

                    $('#local-search').removeClass('localSearchOpen');

                    Centris.fn.wsSend("profiles/" + "bd7ce1ce129348c693b78f331a0cd685" + "/lifestyles", getLocalLogicSelection());
                }
            });

            $(document).on('click', '.ll-score-color-default, .ll-score-color-default > span', function (event) {
                event.preventDefault();
                openLocalLogicPanel();
            });

            $(document).on('click', '.ll-match-score', function (event) {
                event.preventDefault();
            });

            function openLocalLogicPanel() {
                $("html, body").animate({ scrollTop: 0 }, "fast", function () {

                    if ($('#localLogicSection').css("display") == "none") {
                        $('#localLogicSection').show();

                        $('#local-search').addClass('localSearchOpen');

                        $('.ll-match-score').each(function () {
                            this.classList.remove('noAnimation');
                        });
                    }
                });
            }

            function getLocalLogicSelection() {
                return JSON.stringify({ 'LifeStyles': window.localLogicSearchWidget.selection() });
            }
        }

        $('#btn-heatmap').click(function () {

            initLocallogic();

            var locallogicHeatmapInterval = setInterval(function () {
                if (localMapsWidget !== undefined) {
                    localMapsWidget.showUI();
                    window.clearInterval(locallogicHeatmapInterval);
                }
            }, 100);
        });
        /***********************************************************
         Local Logic - Local Maps Widget
         Centris implementation
         ***********************************************************/

        function addDataLayerVirtualTour(mlsId, view) {
            Centris.SendEventToGoogleTagManager({
                'event': 'virtual-tour',
                'mls id': mlsId,
                'view tab': view
            });
        }

        function addDataLayerPhotoViewer(mlsId, view) {
            Centris.SendEventToGoogleTagManager({
                'event': 'photoviewer-enter',
                'mls id': mlsId,
                'view tab': view
            });
        }

    
    </script>



    <!-- Google Tag Manager (noscript) -->
    <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-NC4N8H6" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
    <!-- End Google Tag Manager (noscript) -->
    <script type="text/javascript">

        document.documentElement.setAttribute("data-browser", navigator.userAgent);

        // TODO: Use window.ConsumerSite.labels
        //ressource javascript pour les usermessage Global
        /**/
        Centris.Resources["UserMessage"] = {
	Acres: "ac",
	AlertTitle: "Message",
	All: "All",
	AllFeminin: "All",
	Arpents: "arp.",
	Capital: "Capital",
	Close: "Close",
	ConfirmationTitle: "Confirmation",
	DeleteShapesCancel: "Cancel",
	DeleteShapesDeleteAll: "Delete Shapes",
	DeleteShapesText: "Delete all shapes from the map?",
	DeleteShapesTitle: "Delete Shapes",
	ErrorAjaxMsg: "An error occurred while processing your request. The page will reload.",
	ErrorTitle: "Error",
	FavoriPluriel: "favourites",
	FavoriSingulier: "favourite",
	LimitReachFavorite: "You have reached the limit of {0:N0} favorites.",
	LimitReachLike: "You have reached the limit of {0:N0} favorites.",
	LimitReachDislike: "You have reached the limit of {0:N0} hidden properties.",
	FreeFormText: "All 'FREEFORMTEXT'",
	GeoLocationNotSet: "Centris is not allowed to use your position. Please modify your settings.",
	Hectares: "ha",
	InfoTitle: "Information",
	Interest: "Interest",
	mailFormatError: "Email addresses must respect the format xxx@xxx.xxx and cannot contain accents.",
	MetreCarre: "sqm",
	Month: "Month",
	No: "No",
	NoLimit: "$20,000,000+",
	NoLimitALouer: "$20,000+",
	NoResult: "No results",
	NoResultAutoComplete: "No result found",
	PerMonth: "/month",
	PiedCarre: "sqft",
	pieNoSocioDemoData: "There is no socio-demographic data available for this municipality.",
	ProfilePersistenceError: "Sorry, a connection problem has occurred. Please try again.",
	IdentityProviderException: "Sorry, a connection problem has occurred. Please try again.",
	Properties: "properties",
	PropertiesCount: "properties found",
	Property: "property",
	PropertyCount: "property found",
	PropFavAdded: "The property was added to your favorites.",
	PropFavRemoved: "The property was removed from your favorites.",
	ResidualBalance: "Residual balance",
	Revenus: "Potential Gross Revenue:",
	SearchLabelText: "Search by City, Neighbourhood, Region, Address or Centris No.",
	SelectMessage: "Select an option",
	SendMailFail: "A problem occurred while sending your email. Please try again.",
	SendMailFail429: "The maximum number of messages has been reached. Please try again later.",
	SendMailOK: "Your email was successfully sent.",
	SendMailOKCentris: "Your message was sent successfully! If a response is required, we will reply as soon as possible.",
	SessionExpiredMsg: "Your session has expired due to inactivity.",
	SessionExpiredTitle: "Session Timeout",
	Yes: "Yes",
	RequestTimeCovidRestrictionMessage: "Due to the implementation of a curfew between 8 p.m. and 5 a.m., showing requests are only allowed between 6 a.m. and 7 p.m.",
	ListingPagingFail429: "The maximum number of pages has been reached. Please try again later.",
	ConsentTitle: "Centris\u2019 privacy policy has been updated.",
	ConsentText: "By staying logged in to your account, you consent to your information being processed as set forth in our <a href='https://www.centris.ca/en/terms-use-privacy-policy?tab=PrivacyPolicy' target='_blank'>privacy Policy</a>.",
	ConsentYesButton: "Continue"
};

        Centris.Resources["Photoviewer"] = {
	VirtualTour: "Virtual tour",
	ViewVirtualTour: "View virtual tour"
};

        /**/

        // TODO: Use window.ConsumerSite.languageCode
        window.Centris.Master.Languages = 'en';

        $(function () {
            if ($.blockUI !== undefined) {
                $.blockUI.defaults.overlayCSS.cursor = 'default';
                $.blockUI.defaults.css.backgroundColor = 'rgba(0,0,0,0)';
                $.blockUI.defaults.css.border = '0';
                $.blockUI.defaults.message = '<div class="spinner-border text-primary" role="status">';
            }

            window.ps = new Centris.Master();
            ps.UpdateFavCount(1);
            ps.UpdateDislikeCount(0);
            ps.UpdateMyBrokerCount(0);
            ps.host = 'www.centris.ca';

            if ( true) {
                Centris.fn.wsSend("/UserContext/SetSessionTypeUser");
            }

            // If the ColumnCount is different than the one we have on the server, change it and reload the page to apply the changes.
            var nbCol = getNbColumns();
            var reload = false;
            if (5 != nbCol) {
                Centris.fn.wsSend("/Responsive/UpdateColumnCount", $.stringify({ 'nbColumn': nbCol }), function (result) {
                    if (result.d.Succeeded && reload) {
                        Centris.ContextManager.close();
                        window.location = Centris.ContextManager.getUrl(location.href);
                        return;
                    }
                });
            }


            // Hide popover when you click outside of it.
            // [data-toggle="dropdown"] is a workaround for Bootstrap preventing propagation of the click event.
            $('body, [data-toggle="dropdown"]').on('click', function (e) {
                $('[data-toggle="popover"]').each(function () {
                    if (!$(this).is(e.target) && $(this).has(e.target).length === 0 && $('.popover').has(e.target).length === 0) {
                        $(this).popover('hide');
                    }
                });
            });

            // Initialize popover
            $('[data-toggle="popover"]').popover({
                html: true,
                trigger: "manual",
                container: "body",
                placement: "bottom",
                content: function () {
                    return $('#' + $(this).data("toggle-id")).html();
                }
            });
            $(document).on('click','.popover-body .icon-close', function () {
                $('[data-toggle="popover"]').popover('hide');
            });

            $('.has-tooltip').on("click", function (e) {
                if (window.ConsumerSite.features.activateUserProfile) {
                    var favCount = window.favCount;

                    // if favCount is 0, then prevent navigating to favorites page
                    if (!favCount) {
                        e.preventDefault();
                    }

                    // If the user is logged in, then don't show the popover
                    if (window.loggedIn || favCount) {
                        return;
                    }

                    $('[data-toggle="popover"]', this).popover('toggle');
                }
            });

            // Hide all popover when the window is resized
            $(window).on('resize', function () {
                $('[data-toggle="popover"]').popover('hide');
                ps.UpdateTermsBannerPosition();
            });

            //Set active item in the navbar
            var currentHref = location.href.toString().toLowerCase();
            var isPropertySearchActive = currentHref.indexOf($(".property-search-link").attr("href").toLowerCase()) > -1;

            $('#header a').each(function () {
                $this = $(this);
                var href = $this.attr('href');
                if (href && currentHref.indexOf(href.toLowerCase()) > -1) {
                    // Add a way to bypass the auto selection of the default item
                    if ($this.hasClass('no-auto-select-default'))
                        return;

                    if (isPropertySearchActive && !$this.hasClass('property-search-link'))
                        return;

                    $this.closest('.nav-item').addClass('active');
                    $this.closest('.collapse').collapse('show');
                    $this.closest('.collapse-menu').children('.collapse-btn').addClass('active');
                    $this.addClass('active');
                }
            });
            // End Set active item in the navbar

            // Set jquery validation language
            localizeJqueryValidation(window.Centris.Master.Languages);

            // Header + sidebar

            $('#header .dropdown-hover').mouseover(function () {
                document.body.click(); // Close other dropdowns
                closeUserDrawer();
                $(this).addClass('show');
            });

            $('#header .dropdown-hover').mouseout(function () {
                $(this).removeClass('show');
            });

            function updateNavbarPosition() {
                // Note: implementation of Centris.ScrollToElement must be kept in sync with the navbar behavior.

                var scrollAmount = $(window).scrollTop();
                var promoBannerHeight = $('.promo-container')[0].offsetHeight;
                var $navbar = $('#header .navbar');
                var navbarHeight = $navbar[0].offsetHeight;

                if (scrollAmount > 0 && scrollAmount > promoBannerHeight) {

                    $('#header').css('--header-height', navbarHeight + 'px');
                    if (!$navbar.hasClass('fixed-top')) {
                        $navbar.addClass('fixed-top');
                        $('main').css('padding-top', navbarHeight + 'px');
                    }
                } else {

                    $('#header').css('--header-height', (navbarHeight + promoBannerHeight - 1) + 'px');

                    if ($navbar.hasClass('fixed-top')) {
                        $navbar.removeClass('fixed-top');
                        $('main').css('padding-top', '0');
                    }
                }
            }

            var isUserDrawerOpen = false;
            var sidebarOpen = false;
            
            function getTenantUrl() {
                
                if (sidebarOpen) {
                    closeSidebar();
                }

                var otherTenantUrl = $('#otherTenantUrl').val();
                $('#other-tenant-nav-button').attr("href", otherTenantUrl);
            }

            function openSidebar() {
                sidebarOpen = true;

                // Close user drawer if it's open
                if (isUserDrawerOpen) {
                    handleUserDrawer();
                }

                $('.menu-sidebar').addClass('open');
                $('.menu-sidebar-backdrop').show();
                $('body').addClass('no-scroll');
                $('.menu-sidebar a:not(.disabled), .menu-sidebar button:not(.disabled)').attr('tabIndex', 0);
            }

            function closeSidebar() {
                sidebarOpen = false;
                $('.menu-sidebar').removeClass('open');
                $('.menu-sidebar-backdrop').hide();
                $('body').removeClass('no-scroll');
                $('.menu-sidebar a, .menu-sidebar button').attr('tabIndex', -1);
            }

            function handleUserDrawer() {
                if (isUserDrawerOpen) {
                    closeUserDrawer();
                    return;
                }

                if (sidebarOpen) {
                    closeSidebar();
                }

                openUserDrawer();
            }

            function closeUserDrawer() {
                isUserDrawerOpen = false;
                $('.user-drawer').removeClass('open');
                $('.menu-sidebar-backdrop').hide();
                $('body').removeClass('no-scroll');
            }

            function openUserDrawer() {
                isUserDrawerOpen = true;
                $('.user-drawer').addClass('open');
                $('.menu-sidebar-backdrop').show();
                $('body').addClass('no-scroll');
                $('.user-menu-nav-item').addClass('show');
            }

            $('.mobile-menu-toggle').click(function () {
                if (sidebarOpen) {
                    closeSidebar();
                } else {
                    openSidebar();
                }
            });

            $('.user-menu-nav-link').click(handleUserDrawer)

            $('.other-tenant-item').click(getTenantUrl)

            $('.menu-sidebar-backdrop').click(function () {
                closeSidebar();
                closeUserDrawer();
            });

            $('#header .dropdown').on('show.bs.dropdown', function () {
                closeSidebar();
                closeUserDrawer();
            });

            var sidebarMediaQuery = window.matchMedia('(max-width: 54rem)');
            sidebarMediaQuery.addListener(function (e) {
                if (!e.matches) {
                    // Ensure sidebar is closed when resizing window to desktop view
                    closeSidebar();
                }
            });

            updateNavbarPosition();
            ps.UpdateTermsBannerPosition();
            closeSidebar();
            $(window).scroll(function () {
                updateNavbarPosition();
            });

            // End -- header + sidebar


            if(false == true)
            {
                Centris.SendEventToGoogleTagManager({
                    'event': 'open-consent',
                    'user_id': 'bd7ce1ce129348c693b78f331a0cd685',
                });

                $(document).on("click", ".term-use-banner__button-js", function () {                   
                    Centris.fn.wsSend('/Account/AcceptConsent', null, function () {
                        $(".term-use-banner-js").remove();
                        $("#poweredbycentris").css("margin-bottom", "0");
                        $(".contact-info").css("bottom", "0");
                        Centris.SendEventToGoogleTagManager({
                            'event': 'accept-consent',
                            'user_id': 'bd7ce1ce129348c693b78f331a0cd685',
                        });
                    });
                });
            }

        });
    </script>
    
        <script id="DI-Journey-6AIAAEx6NHFBSoslAAAwbUhJcDFyBwAA" type="text/javascript" src="https://t.ofsys.com/js/Journey/1/6AIAAEx6NHFBSoslAAAwbUhJcDFyBwAA/DI.Journey-min.js"></script><iframe allow="join-ad-interest-group" data-tagging-id="G-2BZHP07X6B" data-load-time="1723380832033" height="0" width="0" src="https://td.doubleclick.net/td/ga/rul?tid=G-2BZHP07X6B&amp;gacid=129051173.1698110424&amp;gtm=45je4880v9103123708z872402024za200zb72402024&amp;dma=0&amp;gcs=G111&amp;gcd=13n3n3n3n5&amp;npa=0&amp;pscdl=noapi&amp;aip=1&amp;fledge=1&amp;frm=0&amp;tag_exp=0&amp;z=372721776" style="display: none; visibility: hidden;"></iframe>

<iframe id="_hjSafeContext_73929290" title="_hjSafeContext" tabindex="-1" aria-hidden="true" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;"></iframe><div id="loom-companion-mv3" ext-id="liecbddmkiiihnedobmlmillhodjkdmb"><section id="shadow-host-companion"></section></div><iframe id="xdomain_cookie_1723380832591" src="https://static.locallogic.co/cookie/xdomain_cookie.html#%7B%22namespace%22%3A%22xdsc%22%2C%22window_origin%22%3A%22https%3A%2F%2Fwww.centris.ca%22%2C%22iframe_origin%22%3A%22https%3A%2F%2Fstatic.locallogic.co%2Fcookie%22%2C%22debug%22%3Afalse%7D" style="display: none;"></iframe><div style="visibility: hidden; position: absolute; width: 100%; top: -10000px; left: 0px; right: 0px; transition: visibility linear 0.3s, opacity 0.3s linear; opacity: 0;"><div style="width: 100%; height: 100%; position: fixed; top: 0px; left: 0px; z-index: 2000000000; background-color: rgb(255, 255, 255); opacity: 0.5;"></div><div style="margin: 0px auto; top: 0px; left: 0px; right: 0px; position: fixed; border: 1px solid rgb(204, 204, 204); z-index: 2000000000; background-color: rgb(255, 255, 255);"><iframe title="recaptcha challenge expires in two minutes" name="c-e1bbph644iop" frameborder="0" scrolling="no" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox allow-storage-access-by-user-activation" src="https://www.google.com/recaptcha/api2/bframe?hl=en&amp;v=_ZpyzC9NQw3gYt1GHTrnprhx&amp;k=6LdHHJQaAAAAAO81RnRXQYPnVO3phMx3i-rElE4t" style="width: 100%; height: 100%;"></iframe></div></div></body>"""

# %%
import langchain
from langchain_openai import ChatOpenAI


def get_model():
    return ChatOpenAI(temperature=0, model_name="gpt-4o-mini")

# %%
# define the data structures

from pydantic import BaseModel, Field

class BaseListing(BaseModel):    
    listing_detail_url: str = Field(description="The url to the real estate site where the details of the listing can be seen")


class RealEstateListing(BaseListing):
    price: float = Field(description="The price of the property")
    building_style: str = Field(description="The kind of property, example detached, split-level, duplex, apartment, etc")
    bedroom_count: str = Field(description="The number of bedrooms in the property")
    full_bathroom_count: int = Field(description="The number of full bathrooms on the property")
    half_bathroom_count: int = Field(description="The number of powder rooms or half baths on the property")
    year_built: int = Field(description="The year the property was built")
    lot_size: int = Field(description="The size of the lot")
    garage_spaces: int = Field(description="The number of parking spaces in the garage. If there is no evidence of a garage, use the value 0.")

# %%
# define the states of the graph
from langgraph.graph import MessagesState
from typing import TypedDict, List

class AgentState(MessagesState):
    email_body: str
    listing_url: BaseListing
    html_content: str
    listing: List[RealEstateListing]
    done: bool
    
class OutputState(TypedDict):
    listing: List[RealEstateListing]
    done: bool

# %% [markdown]
# # Add the nodes of the graph

# %%
from langchain.prompts import PromptTemplate

import requests

# define nodes
analyze_email_prompt = """
You are tasked with analyzing the body of an email of a real estate listing alert and return back
an a list of objects.
The email body is below:
<email_body>
{email_body}
</email_body>
"""


def analyze_email(state: AgentState):
    email_body = state['messages'][-1].content
    model = get_model().with_structured_output(BaseListing)
    prompt = PromptTemplate(template=analyze_email_prompt)    
    runnable = prompt | model
    response = runnable.invoke({"email_body": email_body})

    # augment state
    return {"listing_url": response}


def fetch_url(state: AgentState):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    url = state.get('listing_url').listing_detail_url
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return {
        'html_content': response.content
    }


analyze_listing_page_prompt = """
You are tasked with analyzing some raw HTML and return back a list of objects.
The HTML is not valid as it will be scrubbed of un-important markup for this task.

The HTML content is below
<html_content>
{html_content}
</email_body>
"""

def analyze_listing_page(state: AgentState):
    html_content = state.get('html_content')
    model = get_model().with_structured_output(RealEstateListing)
    prompt = PromptTemplate(template=analyze_listing_page_prompt)

    runnable = prompt | model
    response = runnable.invoke({"html_content": html_content})

    return {"listings": response}    


def finish(state: AgentState) -> None:
    
    return {"done": True}

# %%
from langgraph.graph import StateGraph, END

workflow = StateGraph(AgentState, input=MessagesState, output=OutputState)
workflow.add_node(analyze_email)
workflow.add_node(fetch_url)
workflow.add_node(analyze_listing_page)
workflow.add_node(finish)

workflow.set_entry_point("analyze_email")
workflow.add_edge("analyze_email", "fetch_url")
workflow.add_edge("fetch_url", "analyze_listing_page")
workflow.add_edge("analyze_listing_page", "finish")
workflow.add_edge("finish", END)

graph = workflow.compile()


from IPython.display import Image
Image(graph.get_graph().draw_png())

# %%
graph.invoke({"messages": [("human", sample_email_body)]})
# Out:
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 graph.invoke({"messages": [("human", sample_email_body)]})
#
# File ~/Library/Caches/pypoetry/virtualenvs/realestate-agents-PuNLtYP4-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1333, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1331 else:
#    1332     chunks = []
# -> 1333 for chunk in self.stream(
#    1334     input,
#    1335     config,
#    1336     stream_mode=stream_mode,
#    1337     output_keys=output_keys,
#    1338     interrupt_before=interrupt_before,
#    1339     interrupt_after=interrupt_after,
#    1340     debug=debug,
#    1341     **kwargs,
#    1342 ):
#    1343     if stream_mode == "values":
#    1344         latest = chunk
#
# ...
